# %%
import pandas as pd

badword_df = pd.read_csv('./datasets/badword_dev.tsv' )
badword_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 import pandas as pd
# ----> 3 badword_df = pd.read_csv('./datasets/badword_dev.tsv.csv')
#       4 badword_df
#
# ...

# %%
import pandas as pd

# 결측치 제거
heart_df = heart_df.dropna()

# 중복된 행 제거
heart_df = heart_df.drop_duplicates()

print("Updated DataFrame after removing missing values and duplicates:")
print(heart_df)
# Out:
# Updated DataFrame after removing missing values and duplicates:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# ...

# %%
from sklearn.preprocessing import LabelEncoder

heart_encoder = LabelEncoder()
heart_df['output'] = heart_encoder.fit_transform(heart_df.output)

# %%
print(heart_encoder.classes_)
heart_df
# Out:
# [0 1]
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# ...

# %%
heart_df.output.value_counts()
# Out:
# output
# 1    164
# 0    138
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

features, targets = heart_df.cp, heart_df.output

X_train, X_test, y_train, y_test = train_test_split(features, targets, stratify=targets, test_size=0.2)

# %%
print(X_train.head())
# Out:
# 156    2
# 272    0
# 209    0
# 236    0
# 211    0
# Name: cp, dtype: object

# %%
# X_train의 모든 항목을 문자열로 변환
X_train = X_train.astype(str)

# 이제 파이프라인을 학습시킵니다.
naive_bayes_pipeline.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 5
#       2 X_train = X_train.astype(str)
#       4 # 이제 파이프라인을 학습시킵니다.
# ----> 5 naive_bayes_pipeline.fit(X_train, y_train)
#
# File ~/Desktop/KDT_0900_Cho/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/Desktop/KDT_0900_Cho/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py:416, in Pipeline.fit(self, X, y, **fit_params)
#     390 """Fit the model.
#     391
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

naive_bayes_pipeline = Pipeline([('count_vectorizer', CountVectorizer()), ('multinomialNB', MultinomialNB())])
naive_bayes_pipeline.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 6
#       3 from sklearn.pipeline import Pipeline
#       5 naive_bayes_pipeline = Pipeline([('count_vectorizer', CountVectorizer()), ('multinomialNB', MultinomialNB())])
# ----> 6 naive_bayes_pipeline.fit(X_train, y_train)
#
# File ~/Desktop/KDT_0900_Cho/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/Desktop/KDT_0900_Cho/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py:416, in Pipeline.fit(self, X, y, **fit_params)
# ...
