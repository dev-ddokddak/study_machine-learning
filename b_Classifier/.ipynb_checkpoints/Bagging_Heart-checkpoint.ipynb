# %%
import pandas as pd

# 데이터셋 불러오기
medical_df = pd.read_csv('./datasets/medical_dataset.csv')
lifestyle_df = pd.read_csv('./datasets/lifestyle_dataset.csv')

# 두 데이터셋 합치기
heart_df = pd.concat([medical_df, lifestyle_df], axis=1)
heart_df
# Out:
#           BMI Stroke  PhysicalHealth  AgeCategory  MentalHealth DiffWalking  \
# 0       16.60     No             3.0        55-59          30.0          No
# 1       20.34    Yes             0.0  80 or older           0.0          No
# 2       26.58     No            20.0        65-69          30.0          No
# 3       24.21     No             0.0        75-79           0.0          No
# 4       23.71     No            28.0        40-44           0.0         Yes
# ...       ...    ...             ...          ...           ...         ...
# 319790  27.41     No             7.0        60-64           0.0         Yes
# 319791  29.84     No             0.0        35-39           0.0          No
# 319792  24.24     No             0.0        45-49           0.0          No
# 319793  32.81     No             0.0        25-29           0.0          No
# 319794  46.56     No             0.0  80 or older           0.0          No
#
#        Diabetic  GenHealth Asthma KidneyDisease SkinCancer HeartDisease  \
# 0           Yes  Very good    Yes            No        Yes           No
# 1            No  Very good     No            No         No           No
# 2           Yes       Fair    Yes            No         No           No
# 3            No       Good     No            No        Yes           No
# 4            No  Very good     No            No         No           No
# ...         ...        ...    ...           ...        ...          ...
# 319790      Yes       Fair    Yes            No         No          Yes
# 319791       No  Very good    Yes            No         No           No
# 319792       No       Good     No            No         No           No
# 319793       No       Good     No            No         No           No
# 319794       No       Good     No            No         No           No
#
#            Sex  PatientID Smoking AlcoholDrinking PhysicalActivity  SleepTime  \
# 0       Female     367841     Yes              No              Yes        5.0
# 1       Female     375880      No              No              Yes        7.0
# 2         Male     235382     Yes              No              Yes        8.0
# 3       Female     267437      No              No               No        6.0
# 4       Female     332825      No              No              Yes        8.0
# ...        ...        ...     ...             ...              ...        ...
# 319790    Male     145205     Yes              No               No        6.0
# 319791    Male     409347     Yes              No              Yes        5.0
# 319792  Female     335808      No              No              Yes        6.0
# 319793  Female     414151      No              No               No       12.0
# 319794  Female     280452      No              No              Yes        8.0
#
#             Race  PatientID
# 0          White     367841
# 1          White     375880
# 2          White     235382
# 3          White     267437
# 4          White     332825
# ...          ...        ...
# 319790  Hispanic     145205
# 319791  Hispanic     409347
# 319792  Hispanic     335808
# 319793  Hispanic     414151
# 319794  Hispanic     280452
#
# [319795 rows x 20 columns]

# %%
medical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   BMI             319795 non-null  float64
#  1   Stroke          319795 non-null  object
#  2   PhysicalHealth  319795 non-null  float64
#  3   AgeCategory     319795 non-null  object
#  4   MentalHealth    319795 non-null  float64
#  5   DiffWalking     319795 non-null  object
#  6   Diabetic        319795 non-null  object
#  7   GenHealth       319795 non-null  object
#  8   Asthma          319795 non-null  object
#  9   KidneyDisease   319795 non-null  object
#  10  SkinCancer      319795 non-null  object
#  11  HeartDisease    319795 non-null  object
#  12  Sex             319795 non-null  object
#  13  PatientID       319795 non-null  int64
# dtypes: float64(3), int64(1), object(10)
# memory usage: 34.2+ MB

# %%
lifestyle_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Smoking           319795 non-null  object
#  1   AlcoholDrinking   319795 non-null  object
#  2   PhysicalActivity  319795 non-null  object
#  3   SleepTime         319795 non-null  float64
#  4   Race              319795 non-null  object
#  5   PatientID         319795 non-null  int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 14.6+ MB

# %%
import pandas as pd

# 결측치 확인 
print(heart_df.isna().sum())

# 중복행 확인
print(heart_df.duplicated().sum())
# Out:
# BMI                 0
# Stroke              0
# PhysicalHealth      0
# AgeCategory         0
# MentalHealth        0
# DiffWalking         0
# Diabetic            0
# GenHealth           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# HeartDisease        0
# Sex                 0
# PatientID           0
# Smoking             0
# AlcoholDrinking     0
# PhysicalActivity    0
# SleepTime           0
# Race                0
# PatientID           0
# dtype: int64
# 0

# %%
import pandas as pd

heart_disease_counts = heart_df['HeartDisease'].value_counts()

# 결과 출력
print(heart_disease_counts)
# Out:
# HeartDisease
# No     292422
# Yes     27373
# Name: count, dtype: int64

# %%
# 언더 샘플링
yes_samples = heart_df[heart_df['HeartDisease'] == 'Yes'].sample(n=3000, random_state=42)
no_samples = heart_df[heart_df['HeartDisease'] == 'No'].sample(n=3000, random_state=42)

# 랜덤 샘플링한 데이터를 하나의 데이터프레임으로 합치기
heart_df = pd.concat([yes_samples, no_samples])

# 결과 출력
heart_disease_counts = heart_df['HeartDisease'].value_counts()

# 결과 출력
print(heart_disease_counts)
# Out:
# HeartDisease
# Yes    3000
# No     3000
# Name: count, dtype: int64

# %%
heart_df = heart_df.reset_index(drop=True)
heart_df
# Out:
#         BMI Stroke  PhysicalHealth  AgeCategory  MentalHealth DiffWalking  \
# 0     25.61    Yes            30.0        50-54          30.0          No
# 1     27.12     No             3.0        75-79           0.0          No
# 2     30.90    Yes             4.0        70-74          30.0         Yes
# 3     27.46     No             0.0        70-74           0.0          No
# 4     26.63     No             0.0  80 or older           0.0          No
# ...     ...    ...             ...          ...           ...         ...
# 5995  23.42     No             4.0        18-24           0.0          No
# 5996  28.72     No             0.0        65-69           0.0          No
# 5997  41.60     No             0.0        35-39           0.0          No
# 5998  26.08     No             0.0        30-34           5.0          No
# 5999  28.06     No             0.0        40-44           0.0          No
#
#                      Diabetic  GenHealth Asthma KidneyDisease SkinCancer  \
# 0                          No       Poor     No            No        Yes
# 1     No, borderline diabetes       Good     No            No         No
# 2                         Yes       Fair    Yes           Yes         No
# 3                         Yes  Excellent     No            No         No
# 4                          No  Excellent     No            No        Yes
# ...                       ...        ...    ...           ...        ...
# 5995                       No  Excellent     No            No         No
# 5996                       No  Very good     No            No         No
# 5997                       No  Very good    Yes            No         No
# 5998                       No  Very good     No            No         No
# 5999                       No  Very good     No            No         No
#
#      HeartDisease     Sex  PatientID Smoking AlcoholDrinking PhysicalActivity  \
# 0             Yes  Female     226509     Yes              No              Yes
# 1             Yes    Male     342570     Yes              No              Yes
# 2             Yes  Female     262039      No              No               No
# 3             Yes  Female     183631      No              No              Yes
# 4             Yes    Male     211007     Yes              No               No
# ...           ...     ...        ...     ...             ...              ...
# 5995           No    Male     372542     Yes              No              Yes
# 5996           No  Female     128219      No              No              Yes
# 5997           No    Male     326022     Yes              No              Yes
# 5998           No    Male     282170     Yes              No              Yes
# 5999           No    Male     290267      No              No              Yes
#
#       SleepTime   Race  PatientID
# 0           3.0  Asian     226509
# 1           7.0  White     342570
# 2           7.0  White     262039
# 3           8.0  White     183631
# 4           5.0  White     211007
# ...         ...    ...        ...
# 5995        8.0  White     372542
# 5996        7.0  White     128219
# 5997        6.0  White     326022
# 5998       10.0  White     282170
# 5999        7.0  White     290267
#
# [6000 rows x 20 columns]

# %%
column_counts = heart_df.nunique()
column_counts
# Out:
# BMI                 1279
# Stroke                 2
# PhysicalHealth        31
# AgeCategory           13
# MentalHealth          28
# DiffWalking            2
# Diabetic               4
# GenHealth              5
# Asthma                 2
# KidneyDisease          2
# SkinCancer             2
# HeartDisease           2
# Sex                    2
# PatientID           6000
# Smoking                2
# AlcoholDrinking        2
# PhysicalActivity       2
# SleepTime             20
# Race                   6
# PatientID           6000
# dtype: int64

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BMI               6000 non-null   float64
#  1   Stroke            6000 non-null   object
#  2   PhysicalHealth    6000 non-null   float64
#  3   AgeCategory       6000 non-null   object
#  4   MentalHealth      6000 non-null   float64
#  5   DiffWalking       6000 non-null   object
#  6   Diabetic          6000 non-null   object
#  7   GenHealth         6000 non-null   object
#  8   Asthma            6000 non-null   object
#  9   KidneyDisease     6000 non-null   object
#  10  SkinCancer        6000 non-null   object
#  11  HeartDisease      6000 non-null   object
#  12  Sex               6000 non-null   object
#  13  PatientID         6000 non-null   int64
#  14  Smoking           6000 non-null   object
#  15  AlcoholDrinking   6000 non-null   object
#  16  PhysicalActivity  6000 non-null   object
#  17  SleepTime         6000 non-null   float64
#  18  Race              6000 non-null   object
#  19  PatientID         6000 non-null   int64
# dtypes: float64(4), int64(2), object(14)
# memory usage: 937.6+ KB

# %%
from sklearn.preprocessing import LabelEncoder

# HeartDisease 데이터프레임에서 객체 타입 컬럼 선택
obj_columns = ['HeartDisease', 'Smoking', 'AlcoholDrinking', 'Stroke', 'DiffWalking', 'Sex', 'AgeCategory', 'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'Asthma', 'KidneyDisease', 'SkinCancer']

# 레이블 인코더 초기화
encoders = []

# 레이블 인코딩 수행
for column in obj_columns:
    encoder = LabelEncoder()
    heart_df[column] = encoder.fit_transform(heart_df[column].tolist())
    encoders.append(encoder)
    print(encoder.classes_)
# Out:
# ['No' 'Yes']
# ['No' 'Yes']
# ['No' 'Yes']
# ['No' 'Yes']
# ['No' 'Yes']
# ['Female' 'Male']
# ['18-24' '25-29' '30-34' '35-39' '40-44' '45-49' '50-54' '55-59' '60-64'
#  '65-69' '70-74' '75-79' '80 or older']
# ['American Indian/Alaskan Native' 'Asian' 'Black' 'Hispanic' 'Other'
#  'White']
# ['No' 'No, borderline diabetes' 'Yes' 'Yes (during pregnancy)']
# ['No' 'Yes']
# ['Excellent' 'Fair' 'Good' 'Poor' 'Very good']
# ['No' 'Yes']
# ['No' 'Yes']
# ['No' 'Yes']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(5, 4))
correlation_matrix = heart_df.corr()
sns.heatmap(correlation_matrix, cmap="Oranges")
# Out:
# <Axes: >

# %%
heart_df.iloc[:, 1:].hist(figsize=(20, 20), bins=80)
# Out:
# array([[<Axes: title={'center': 'Stroke'}>,
#         <Axes: title={'center': 'PhysicalHealth'}>,
#         <Axes: title={'center': 'AgeCategory'}>,
#         <Axes: title={'center': 'MentalHealth'}>],
#        [<Axes: title={'center': 'DiffWalking'}>,
#         <Axes: title={'center': 'Diabetic'}>,
#         <Axes: title={'center': 'GenHealth'}>,
#         <Axes: title={'center': 'Asthma'}>],
#        [<Axes: title={'center': 'KidneyDisease'}>,
#         <Axes: title={'center': 'SkinCancer'}>,
#         <Axes: title={'center': 'HeartDisease'}>,
#         <Axes: title={'center': 'Sex'}>],
#        [<Axes: title={'center': 'PatientID'}>,
#         <Axes: title={'center': 'Smoking'}>,
#         <Axes: title={'center': 'AlcoholDrinking'}>,
#         <Axes: title={'center': 'PhysicalActivity'}>],
#        [<Axes: title={'center': 'SleepTime'}>,
#         <Axes: title={'center': 'Race'}>,
#         <Axes: title={'center': 'PatientID'}>, <Axes: >]], dtype=object)

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.ensemble import RandomForestClassifier

param_grid = {
    'max_depth': [4, 6, 8, 10, 12],
    'min_samples_split': [6, 12, 18, 24],
    'min_samples_leaf': [4, 8, 16]
}

random_forest_classifier = RandomForestClassifier(n_estimators=100)

features, targets = heart_df.drop('HeartDisease', axis=1), heart_df.HeartDisease

X_train, X_test, y_train, y_test = train_test_split(features, targets, stratify=targets, test_size=0.3)

grid_random_forest = GridSearchCV(random_forest_classifier, param_grid=param_grid, cv=10, n_jobs=4)

grid_random_forest.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestClassifier(), n_jobs=4,
#              param_grid={'max_depth': [4, 6, 8, 10, 12],
#                          'min_samples_leaf': [4, 8, 16],
#                          'min_samples_split': [6, 12, 18, 24]})

# %%
# DataFrame으로 변환
scores_df = pd.DataFrame(grid_random_forest.cv_results_)
scores_df[['params', 'mean_test_score', 'rank_test_score', 
           'split0_test_score', 'split1_test_score', 'split2_test_score']].sort_values(by='rank_test_score')
# Out:
#                                                params  mean_test_score  \
# 18  {'max_depth': 6, 'min_samples_leaf': 8, 'min_s...         0.768095
# 22  {'max_depth': 6, 'min_samples_leaf': 16, 'min_...         0.767857
# 29  {'max_depth': 8, 'min_samples_leaf': 8, 'min_s...         0.767143
# 30  {'max_depth': 8, 'min_samples_leaf': 8, 'min_s...         0.766905
# 25  {'max_depth': 8, 'min_samples_leaf': 4, 'min_s...         0.766905
# 36  {'max_depth': 10, 'min_samples_leaf': 4, 'min_...         0.766667
# 31  {'max_depth': 8, 'min_samples_leaf': 8, 'min_s...         0.766667
# 13  {'max_depth': 6, 'min_samples_leaf': 4, 'min_s...         0.766429
# 45  {'max_depth': 10, 'min_samples_leaf': 16, 'min...         0.766429
# 41  {'max_depth': 10, 'min_samples_leaf': 8, 'min_...         0.766429
# 53  {'max_depth': 12, 'min_samples_leaf': 8, 'min_...         0.766190
# 57  {'max_depth': 12, 'min_samples_leaf': 16, 'min...         0.766190
# 40  {'max_depth': 10, 'min_samples_leaf': 8, 'min_...         0.766190
# 59  {'max_depth': 12, 'min_samples_leaf': 16, 'min...         0.766190
# 44  {'max_depth': 10, 'min_samples_leaf': 16, 'min...         0.765952
# 42  {'max_depth': 10, 'min_samples_leaf': 8, 'min_...         0.765952
# 52  {'max_depth': 12, 'min_samples_leaf': 8, 'min_...         0.765952
# 47  {'max_depth': 10, 'min_samples_leaf': 16, 'min...         0.765952
# 23  {'max_depth': 6, 'min_samples_leaf': 16, 'min_...         0.765238
# 43  {'max_depth': 10, 'min_samples_leaf': 8, 'min_...         0.765238
# 35  {'max_depth': 8, 'min_samples_leaf': 16, 'min_...         0.765000
# 14  {'max_depth': 6, 'min_samples_leaf': 4, 'min_s...         0.765000
# 56  {'max_depth': 12, 'min_samples_leaf': 16, 'min...         0.765000
# 55  {'max_depth': 12, 'min_samples_leaf': 8, 'min_...         0.764762
# 38  {'max_depth': 10, 'min_samples_leaf': 4, 'min_...         0.764762
# 37  {'max_depth': 10, 'min_samples_leaf': 4, 'min_...         0.764762
# 26  {'max_depth': 8, 'min_samples_leaf': 4, 'min_s...         0.764762
# 27  {'max_depth': 8, 'min_samples_leaf': 4, 'min_s...         0.764762
# 34  {'max_depth': 8, 'min_samples_leaf': 16, 'min_...         0.764762
# 58  {'max_depth': 12, 'min_samples_leaf': 16, 'min...         0.764524
# 49  {'max_depth': 12, 'min_samples_leaf': 4, 'min_...         0.764524
# 32  {'max_depth': 8, 'min_samples_leaf': 16, 'min_...         0.764524
# 21  {'max_depth': 6, 'min_samples_leaf': 16, 'min_...         0.764286
# 51  {'max_depth': 12, 'min_samples_leaf': 4, 'min_...         0.764048
# 48  {'max_depth': 12, 'min_samples_leaf': 4, 'min_...         0.764048
# 54  {'max_depth': 12, 'min_samples_leaf': 8, 'min_...         0.763810
# 12  {'max_depth': 6, 'min_samples_leaf': 4, 'min_s...         0.763810
# 39  {'max_depth': 10, 'min_samples_leaf': 4, 'min_...         0.763810
# 20  {'max_depth': 6, 'min_samples_leaf': 16, 'min_...         0.763333
# 24  {'max_depth': 8, 'min_samples_leaf': 4, 'min_s...         0.763095
# 16  {'max_depth': 6, 'min_samples_leaf': 8, 'min_s...         0.763095
# 50  {'max_depth': 12, 'min_samples_leaf': 4, 'min_...         0.762857
# 46  {'max_depth': 10, 'min_samples_leaf': 16, 'min...         0.762857
# 19  {'max_depth': 6, 'min_samples_leaf': 8, 'min_s...         0.762619
# 17  {'max_depth': 6, 'min_samples_leaf': 8, 'min_s...         0.762619
# 33  {'max_depth': 8, 'min_samples_leaf': 16, 'min_...         0.762619
# 28  {'max_depth': 8, 'min_samples_leaf': 8, 'min_s...         0.761667
# 15  {'max_depth': 6, 'min_samples_leaf': 4, 'min_s...         0.761190
# 3   {'max_depth': 4, 'min_samples_leaf': 4, 'min_s...         0.760714
# 6   {'max_depth': 4, 'min_samples_leaf': 8, 'min_s...         0.759524
# 2   {'max_depth': 4, 'min_samples_leaf': 4, 'min_s...         0.757857
# 9   {'max_depth': 4, 'min_samples_leaf': 16, 'min_...         0.757619
# 0   {'max_depth': 4, 'min_samples_leaf': 4, 'min_s...         0.757381
# 11  {'max_depth': 4, 'min_samples_leaf': 16, 'min_...         0.757143
# 4   {'max_depth': 4, 'min_samples_leaf': 8, 'min_s...         0.756905
# 5   {'max_depth': 4, 'min_samples_leaf': 8, 'min_s...         0.755476
# 8   {'max_depth': 4, 'min_samples_leaf': 16, 'min_...         0.755476
# 7   {'max_depth': 4, 'min_samples_leaf': 8, 'min_s...         0.755000
# 1   {'max_depth': 4, 'min_samples_leaf': 4, 'min_s...         0.753571
# 10  {'max_depth': 4, 'min_samples_leaf': 16, 'min_...         0.752619
#
#     rank_test_score  split0_test_score  split1_test_score  split2_test_score
# 18                1           0.761905           0.790476           0.754762
# 22                2           0.778571           0.802381           0.761905
# 29                3           0.783333           0.790476           0.759524
# 30                4           0.764286           0.795238           0.759524
# 25                4           0.778571           0.785714           0.752381
# 36                6           0.778571           0.790476           0.766667
# 31                6           0.773810           0.792857           0.766667
# 13                8           0.769048           0.792857           0.769048
# 45                9           0.776190           0.788095           0.761905
# 41                9           0.788095           0.788095           0.759524
# 53               11           0.771429           0.783333           0.769048
# 57               12           0.780952           0.792857           0.761905
# 40               12           0.773810           0.780952           0.766667
# 59               12           0.780952           0.797619           0.757143
# 44               15           0.771429           0.790476           0.764286
# 42               15           0.783333           0.795238           0.754762
# 52               15           0.780952           0.788095           0.752381
# 47               15           0.769048           0.788095           0.761905
# 23               19           0.766667           0.795238           0.759524
# 43               19           0.764286           0.773810           0.754762
# 35               21           0.771429           0.795238           0.761905
# 14               21           0.769048           0.790476           0.764286
# 56               21           0.780952           0.783333           0.759524
# 55               24           0.780952           0.778571           0.761905
# 38               24           0.776190           0.790476           0.754762
# 37               24           0.769048           0.780952           0.764286
# 26               24           0.778571           0.785714           0.757143
# 27               24           0.773810           0.795238           0.764286
# 34               24           0.776190           0.778571           0.757143
# 58               30           0.780952           0.797619           0.764286
# 49               31           0.771429           0.788095           0.757143
# 32               31           0.773810           0.790476           0.764286
# 21               33           0.771429           0.797619           0.759524
# 51               34           0.771429           0.785714           0.752381
# 48               34           0.776190           0.797619           0.754762
# 54               36           0.773810           0.776190           0.752381
# 12               36           0.764286           0.790476           0.769048
# 39               36           0.771429           0.778571           0.761905
# 20               39           0.769048           0.783333           0.780952
# 24               40           0.764286           0.797619           0.754762
# 16               40           0.776190           0.790476           0.764286
# 50               42           0.771429           0.778571           0.759524
# 46               42           0.773810           0.783333           0.764286
# 19               44           0.764286           0.788095           0.771429
# 17               44           0.771429           0.790476           0.769048
# 33               44           0.773810           0.788095           0.766667
# 28               47           0.776190           0.785714           0.754762
# 15               48           0.747619           0.785714           0.764286
# 3                49           0.759524           0.785714           0.771429
# 6                50           0.761905           0.778571           0.769048
# 2                51           0.757143           0.773810           0.778571
# 9                52           0.742857           0.776190           0.771429
# 0                53           0.750000           0.783333           0.766667
# 11               54           0.764286           0.771429           0.776190
# 4                55           0.742857           0.778571           0.778571
# 5                56           0.754762           0.766667           0.776190
# 8                56           0.757143           0.766667           0.778571
# 7                58           0.752381           0.776190           0.773810
# 1                59           0.752381           0.783333           0.766667
# 10               60           0.750000           0.771429           0.771429

# %%
from sklearn.metrics import accuracy_score, precision_score , recall_score , confusion_matrix, ConfusionMatrixDisplay, f1_score, roc_auc_score
# 타겟 데이터와 예측 객체를 전달받는다.
def get_evaluation(y_test, prediction, classifier=None, X_test=None):
#     오차 행렬
    confusion = confusion_matrix(y_test, prediction)
#     정확도
    accuracy = accuracy_score(y_test , prediction)
#     정밀도
    precision = precision_score(y_test , prediction)
#     재현율
    recall = recall_score(y_test , prediction)
#     F1 score
    f1 = f1_score(y_test, prediction)
#     ROC-AUC
    roc_auc = roc_auc_score(y_test, prediction)

    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1:{3:.4f}, AUC:{4:.4f}'.format(accuracy , precision ,recall, f1, roc_auc))
    print("#" * 75)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
prediction = grid_random_forest.predict(X_test)
get_evaluation(y_test, prediction, grid_random_forest, X_test)
# Out:
# 오차 행렬
# [[624 276]
#  [160 740]]
# 정확도: 0.7578, 정밀도: 0.7283, 재현율: 0.8222, F1:0.7724, AUC:0.7578
# ###########################################################################

# %%
def get_evaluation_by_thresholds(y_test, prediction_proba_class1, thresholds):
    
    for threshold in thresholds:
        binarizer = Binarizer(threshold=threshold).fit(prediction_proba_class1) 
        custom_prediction = binarizer.transform(prediction_proba_class1)
        print('임곗값:', threshold)
        get_evaluation(y_test, custom_prediction)

# %%
from sklearn.preprocessing import Binarizer
from sklearn.metrics import precision_recall_curve

prediction_prob = grid_random_forest.predict_proba(X_test)
prediction_prob_class1 = prediction_prob[:, 1].reshape(-1, 1)
precision, recall, thresholds = precision_recall_curve(y_test, prediction_prob_class1)
get_evaluation_by_thresholds(y_test, prediction_prob_class1, thresholds)
# Out:
# 임곗값: 0.0856005701385972
# 오차 행렬
# [[  1 899]
#  [  0 900]]
# 정확도: 0.5006, 정밀도: 0.5003, 재현율: 1.0000, F1:0.6669, AUC:0.5006
# ###########################################################################
# 임곗값: 0.0856786877689895
# 오차 행렬
# [[  2 898]
#  [  0 900]]
# 정확도: 0.5011, 정밀도: 0.5006, 재현율: 1.0000, F1:0.6672, AUC:0.5011
# ###########################################################################
# 임곗값: 0.08592672769026899
# 오차 행렬
# [[  3 897]
#  [  0 900]]
# 정확도: 0.5017, 정밀도: 0.5008, 재현율: 1.0000, F1:0.6674, AUC:0.5017
# ###########################################################################
# 임곗값: 0.0877432564886451
# 오차 행렬
# [[  4 896]
#  [  0 900]]
# 정확도: 0.5022, 정밀도: 0.5011, 재현율: 1.0000, F1:0.6677, AUC:0.5022
# ###########################################################################
# 임곗값: 0.08820275620931389
# 오차 행렬
# [[  5 895]
#  [  0 900]]
# 정확도: 0.5028, 정밀도: 0.5014, 재현율: 1.0000, F1:0.6679, AUC:0.5028
# ###########################################################################
# 임곗값: 0.08929616522884165
# 오차 행렬
# [[  6 894]
#  [  0 900]]
# 정확도: 0.5033, 정밀도: 0.5017, 재현율: 1.0000, F1:0.6682, AUC:0.5033
# ###########################################################################
# 임곗값: 0.09001637759297183
# 오차 행렬
# [[  7 893]
#  [  0 900]]
# 정확도: 0.5039, 정밀도: 0.5020, 재현율: 1.0000, F1:0.6684, AUC:0.5039
# ###########################################################################
# 임곗값: 0.09392421284422146
# 오차 행렬
# [[  8 892]
#  [  0 900]]
# 정확도: 0.5044, 정밀도: 0.5022, 재현율: 1.0000, F1:0.6686, AUC:0.5044
# ###########################################################################
# 임곗값: 0.09421036125787077
# 오차 행렬
# [[  9 891]
#  [  0 900]]
# 정확도: 0.5050, 정밀도: 0.5025, 재현율: 1.0000, F1:0.6689, AUC:0.5050
# ###########################################################################
# 임곗값: 0.09436415699244093
# 오차 행렬
# [[ 10 890]
#  [  0 900]]
# 정확도: 0.5056, 정밀도: 0.5028, 재현율: 1.0000, F1:0.6691, AUC:0.5056
# ###########################################################################
# 임곗값: 0.09521449231148801
# 오차 행렬
# [[ 11 889]
#  [  0 900]]
# 정확도: 0.5061, 정밀도: 0.5031, 재현율: 1.0000, F1:0.6694, AUC:0.5061
# ###########################################################################
# 임곗값: 0.09570897470924022
# 오차 행렬
# [[ 12 888]
#  [  0 900]]
# 정확도: 0.5067, 정밀도: 0.5034, 재현율: 1.0000, F1:0.6696, AUC:0.5067
# ###########################################################################
# 임곗값: 0.09577401367727037
# 오차 행렬
# [[ 13 887]
#  [  0 900]]
# 정확도: 0.5072, 정밀도: 0.5036, 재현율: 1.0000, F1:0.6699, AUC:0.5072
# ###########################################################################
# 임곗값: 0.09596445190984104
# 오차 행렬
# [[ 14 886]
#  [  0 900]]
# 정확도: 0.5078, 정밀도: 0.5039, 재현율: 1.0000, F1:0.6701, AUC:0.5078
# ###########################################################################
# 임곗값: 0.09640448772467218
# 오차 행렬
# [[ 15 885]
#  [  0 900]]
# 정확도: 0.5083, 정밀도: 0.5042, 재현율: 1.0000, F1:0.6704, AUC:0.5083
# ###########################################################################
# 임곗값: 0.09666351089416972
# 오차 행렬
# [[ 16 884]
#  [  0 900]]
# 정확도: 0.5089, 정밀도: 0.5045, 재현율: 1.0000, F1:0.6706, AUC:0.5089
# ###########################################################################
# 임곗값: 0.0970998280508041
# 오차 행렬
# [[ 16 884]
#  [  1 899]]
# 정확도: 0.5083, 정밀도: 0.5042, 재현율: 0.9989, F1:0.6701, AUC:0.5083
# ###########################################################################
# 임곗값: 0.09711551367710322
# 오차 행렬
# [[ 17 883]
#  [  1 899]]
# 정확도: 0.5089, 정밀도: 0.5045, 재현율: 0.9989, F1:0.6704, AUC:0.5089
# ###########################################################################
# 임곗값: 0.09753573125273177
# 오차 행렬
# [[ 18 882]
#  [  1 899]]
# 정확도: 0.5094, 정밀도: 0.5048, 재현율: 0.9989, F1:0.6706, AUC:0.5094
# ###########################################################################
# 임곗값: 0.09822263701221959
# 오차 행렬
# [[ 19 881]
#  [  1 899]]
# 정확도: 0.5100, 정밀도: 0.5051, 재현율: 0.9989, F1:0.6709, AUC:0.5100
# ###########################################################################
# 임곗값: 0.09910826971927003
# 오차 행렬
# [[ 20 880]
#  [  1 899]]
# 정확도: 0.5106, 정밀도: 0.5053, 재현율: 0.9989, F1:0.6711, AUC:0.5106
# ###########################################################################
# 임곗값: 0.10005450138355593
# 오차 행렬
# [[ 21 879]
#  [  1 899]]
# 정확도: 0.5111, 정밀도: 0.5056, 재현율: 0.9989, F1:0.6714, AUC:0.5111
# ###########################################################################
# 임곗값: 0.10063172183721816
# 오차 행렬
# [[ 22 878]
#  [  1 899]]
# 정확도: 0.5117, 정밀도: 0.5059, 재현율: 0.9989, F1:0.6716, AUC:0.5117
# ###########################################################################
# 임곗값: 0.10066440301620672
# 오차 행렬
# [[ 23 877]
#  [  1 899]]
# 정확도: 0.5122, 정밀도: 0.5062, 재현율: 0.9989, F1:0.6719, AUC:0.5122
# ###########################################################################
# 임곗값: 0.10271757731594237
# 오차 행렬
# [[ 24 876]
#  [  1 899]]
# 정확도: 0.5128, 정밀도: 0.5065, 재현율: 0.9989, F1:0.6721, AUC:0.5128
# ###########################################################################
# 임곗값: 0.10512185970540107
# 오차 행렬
# [[ 25 875]
#  [  1 899]]
# 정확도: 0.5133, 정밀도: 0.5068, 재현율: 0.9989, F1:0.6724, AUC:0.5133
# ###########################################################################
# 임곗값: 0.10701028761387216
# 오차 행렬
# [[ 26 874]
#  [  1 899]]
# 정확도: 0.5139, 정밀도: 0.5071, 재현율: 0.9989, F1:0.6727, AUC:0.5139
# ###########################################################################
# 임곗값: 0.10710018704132397
# 오차 행렬
# [[ 27 873]
#  [  1 899]]
# 정확도: 0.5144, 정밀도: 0.5073, 재현율: 0.9989, F1:0.6729, AUC:0.5144
# ###########################################################################
# 임곗값: 0.10766398055042822
# 오차 행렬
# [[ 28 872]
#  [  1 899]]
# 정확도: 0.5150, 정밀도: 0.5076, 재현율: 0.9989, F1:0.6732, AUC:0.5150
# ###########################################################################
# 임곗값: 0.10780246247483236
# 오차 행렬
# [[ 28 872]
#  [  2 898]]
# 정확도: 0.5144, 정밀도: 0.5073, 재현율: 0.9978, F1:0.6727, AUC:0.5144
# ###########################################################################
# 임곗값: 0.10791240816231787
# 오차 행렬
# [[ 29 871]
#  [  2 898]]
# 정확도: 0.5150, 정밀도: 0.5076, 재현율: 0.9978, F1:0.6729, AUC:0.5150
# ###########################################################################
# 임곗값: 0.1083218096999925
# 오차 행렬
# [[ 30 870]
#  [  2 898]]
# 정확도: 0.5156, 정밀도: 0.5079, 재현율: 0.9978, F1:0.6732, AUC:0.5156
# ###########################################################################
# 임곗값: 0.10836886191907961
# 오차 행렬
# [[ 31 869]
#  [  2 898]]
# 정확도: 0.5161, 정밀도: 0.5082, 재현율: 0.9978, F1:0.6734, AUC:0.5161
# ###########################################################################
# 임곗값: 0.10867139217188132
# 오차 행렬
# [[ 32 868]
#  [  2 898]]
# 정확도: 0.5167, 정밀도: 0.5085, 재현율: 0.9978, F1:0.6737, AUC:0.5167
# ###########################################################################
# 임곗값: 0.10869575670760925
# 오차 행렬
# [[ 33 867]
#  [  2 898]]
# 정확도: 0.5172, 정밀도: 0.5088, 재현율: 0.9978, F1:0.6739, AUC:0.5172
# ###########################################################################
# 임곗값: 0.10883351647800023
# 오차 행렬
# [[ 34 866]
#  [  2 898]]
# 정확도: 0.5178, 정밀도: 0.5091, 재현율: 0.9978, F1:0.6742, AUC:0.5178
# ###########################################################################
# 임곗값: 0.10901419844761512
# 오차 행렬
# [[ 35 865]
#  [  2 898]]
# 정확도: 0.5183, 정밀도: 0.5094, 재현율: 0.9978, F1:0.6744, AUC:0.5183
# ###########################################################################
# 임곗값: 0.10957239144823169
# 오차 행렬
# [[ 36 864]
#  [  2 898]]
# 정확도: 0.5189, 정밀도: 0.5096, 재현율: 0.9978, F1:0.6747, AUC:0.5189
# ###########################################################################
# 임곗값: 0.11008078033121808
# 오차 행렬
# [[ 36 864]
#  [  3 897]]
# 정확도: 0.5183, 정밀도: 0.5094, 재현율: 0.9967, F1:0.6742, AUC:0.5183
# ###########################################################################
# 임곗값: 0.11009928696923221
# 오차 행렬
# [[ 37 863]
#  [  3 897]]
# 정확도: 0.5189, 정밀도: 0.5097, 재현율: 0.9967, F1:0.6744, AUC:0.5189
# ###########################################################################
# 임곗값: 0.11014125645410729
# 오차 행렬
# [[ 38 862]
#  [  3 897]]
# 정확도: 0.5194, 정밀도: 0.5099, 재현율: 0.9967, F1:0.6747, AUC:0.5194
# ###########################################################################
# 임곗값: 0.11092594434376656
# 오차 행렬
# [[ 39 861]
#  [  3 897]]
# 정확도: 0.5200, 정밀도: 0.5102, 재현율: 0.9967, F1:0.6749, AUC:0.5200
# ###########################################################################
# 임곗값: 0.11102876930173751
# 오차 행렬
# [[ 40 860]
#  [  3 897]]
# 정확도: 0.5206, 정밀도: 0.5105, 재현율: 0.9967, F1:0.6752, AUC:0.5206
# ###########################################################################
# 임곗값: 0.11157105264481347
# 오차 행렬
# [[ 41 859]
#  [  3 897]]
# 정확도: 0.5211, 정밀도: 0.5108, 재현율: 0.9967, F1:0.6755, AUC:0.5211
# ###########################################################################
# 임곗값: 0.11220520659694255
# 오차 행렬
# [[ 42 858]
#  [  3 897]]
# 정확도: 0.5217, 정밀도: 0.5111, 재현율: 0.9967, F1:0.6757, AUC:0.5217
# ###########################################################################
# 임곗값: 0.11240857209436844
# 오차 행렬
# [[ 43 857]
#  [  3 897]]
# 정확도: 0.5222, 정밀도: 0.5114, 재현율: 0.9967, F1:0.6760, AUC:0.5222
# ###########################################################################
# 임곗값: 0.11280370975480287
# 오차 행렬
# [[ 44 856]
#  [  3 897]]
# 정확도: 0.5228, 정밀도: 0.5117, 재현율: 0.9967, F1:0.6762, AUC:0.5228
# ###########################################################################
# 임곗값: 0.11337128593797749
# 오차 행렬
# [[ 45 855]
#  [  3 897]]
# 정확도: 0.5233, 정밀도: 0.5120, 재현율: 0.9967, F1:0.6765, AUC:0.5233
# ###########################################################################
# 임곗값: 0.11404561723271538
# 오차 행렬
# [[ 46 854]
#  [  3 897]]
# 정확도: 0.5239, 정밀도: 0.5123, 재현율: 0.9967, F1:0.6767, AUC:0.5239
# ###########################################################################
# 임곗값: 0.11465631864006708
# 오차 행렬
# [[ 47 853]
#  [  3 897]]
# 정확도: 0.5244, 정밀도: 0.5126, 재현율: 0.9967, F1:0.6770, AUC:0.5244
# ###########################################################################
# 임곗값: 0.11511171407950149
# 오차 행렬
# [[ 48 852]
#  [  3 897]]
# 정확도: 0.5250, 정밀도: 0.5129, 재현율: 0.9967, F1:0.6772, AUC:0.5250
# ###########################################################################
# 임곗값: 0.11516498280730281
# 오차 행렬
# [[ 49 851]
#  [  3 897]]
# 정확도: 0.5256, 정밀도: 0.5132, 재현율: 0.9967, F1:0.6775, AUC:0.5256
# ###########################################################################
# 임곗값: 0.11543296611379654
# 오차 행렬
# [[ 50 850]
#  [  3 897]]
# 정확도: 0.5261, 정밀도: 0.5135, 재현율: 0.9967, F1:0.6777, AUC:0.5261
# ###########################################################################
# 임곗값: 0.11562945635931404
# 오차 행렬
# [[ 51 849]
#  [  3 897]]
# 정확도: 0.5267, 정밀도: 0.5137, 재현율: 0.9967, F1:0.6780, AUC:0.5267
# ###########################################################################
# 임곗값: 0.11564293109792467
# 오차 행렬
# [[ 52 848]
#  [  3 897]]
# 정확도: 0.5272, 정밀도: 0.5140, 재현율: 0.9967, F1:0.6783, AUC:0.5272
# ###########################################################################
# 임곗값: 0.11565897852067275
# 오차 행렬
# [[ 53 847]
#  [  3 897]]
# 정확도: 0.5278, 정밀도: 0.5143, 재현율: 0.9967, F1:0.6785, AUC:0.5278
# ###########################################################################
# 임곗값: 0.11594933978646343
# 오차 행렬
# [[ 54 846]
#  [  3 897]]
# 정확도: 0.5283, 정밀도: 0.5146, 재현율: 0.9967, F1:0.6788, AUC:0.5283
# ###########################################################################
# 임곗값: 0.11612953462536454
# 오차 행렬
# [[ 55 845]
#  [  3 897]]
# 정확도: 0.5289, 정밀도: 0.5149, 재현율: 0.9967, F1:0.6790, AUC:0.5289
# ###########################################################################
# 임곗값: 0.11671542562342627
# 오차 행렬
# [[ 56 844]
#  [  3 897]]
# 정확도: 0.5294, 정밀도: 0.5152, 재현율: 0.9967, F1:0.6793, AUC:0.5294
# ###########################################################################
# 임곗값: 0.11684694577864052
# 오차 행렬
# [[ 57 843]
#  [  3 897]]
# 정확도: 0.5300, 정밀도: 0.5155, 재현율: 0.9967, F1:0.6795, AUC:0.5300
# ###########################################################################
# 임곗값: 0.11686419662687561
# 오차 행렬
# [[ 58 842]
#  [  3 897]]
# 정확도: 0.5306, 정밀도: 0.5158, 재현율: 0.9967, F1:0.6798, AUC:0.5306
# ###########################################################################
# 임곗값: 0.11694950980068528
# 오차 행렬
# [[ 59 841]
#  [  3 897]]
# 정확도: 0.5311, 정밀도: 0.5161, 재현율: 0.9967, F1:0.6801, AUC:0.5311
# ###########################################################################
# 임곗값: 0.11714159049724004
# 오차 행렬
# [[ 60 840]
#  [  3 897]]
# 정확도: 0.5317, 정밀도: 0.5164, 재현율: 0.9967, F1:0.6803, AUC:0.5317
# ###########################################################################
# 임곗값: 0.11762006972128933
# 오차 행렬
# [[ 61 839]
#  [  3 897]]
# 정확도: 0.5322, 정밀도: 0.5167, 재현율: 0.9967, F1:0.6806, AUC:0.5322
# ###########################################################################
# 임곗값: 0.11783758757428514
# 오차 행렬
# [[ 62 838]
#  [  3 897]]
# 정확도: 0.5328, 정밀도: 0.5170, 재현율: 0.9967, F1:0.6808, AUC:0.5328
# ###########################################################################
# 임곗값: 0.11787873287730259
# 오차 행렬
# [[ 63 837]
#  [  3 897]]
# 정확도: 0.5333, 정밀도: 0.5173, 재현율: 0.9967, F1:0.6811, AUC:0.5333
# ###########################################################################
# 임곗값: 0.11921283315393721
# 오차 행렬
# [[ 64 836]
#  [  3 897]]
# 정확도: 0.5339, 정밀도: 0.5176, 재현율: 0.9967, F1:0.6814, AUC:0.5339
# ###########################################################################
# 임곗값: 0.1194807899317248
# 오차 행렬
# [[ 65 835]
#  [  3 897]]
# 정확도: 0.5344, 정밀도: 0.5179, 재현율: 0.9967, F1:0.6816, AUC:0.5344
# ###########################################################################
# 임곗값: 0.11956499409412558
# 오차 행렬
# [[ 66 834]
#  [  3 897]]
# 정확도: 0.5350, 정밀도: 0.5182, 재현율: 0.9967, F1:0.6819, AUC:0.5350
# ###########################################################################
# 임곗값: 0.11958894295758812
# 오차 행렬
# [[ 67 833]
#  [  3 897]]
# 정확도: 0.5356, 정밀도: 0.5185, 재현율: 0.9967, F1:0.6821, AUC:0.5356
# ###########################################################################
# 임곗값: 0.11962282806055663
# 오차 행렬
# [[ 68 832]
#  [  3 897]]
# 정확도: 0.5361, 정밀도: 0.5188, 재현율: 0.9967, F1:0.6824, AUC:0.5361
# ###########################################################################
# 임곗값: 0.12044898295409348
# 오차 행렬
# [[ 69 831]
#  [  3 897]]
# 정확도: 0.5367, 정밀도: 0.5191, 재현율: 0.9967, F1:0.6826, AUC:0.5367
# ###########################################################################
# 임곗값: 0.12105170199427663
# 오차 행렬
# [[ 70 830]
#  [  3 897]]
# 정확도: 0.5372, 정밀도: 0.5194, 재현율: 0.9967, F1:0.6829, AUC:0.5372
# ###########################################################################
# 임곗값: 0.12187898616928755
# 오차 행렬
# [[ 71 829]
#  [  3 897]]
# 정확도: 0.5378, 정밀도: 0.5197, 재현율: 0.9967, F1:0.6832, AUC:0.5378
# ###########################################################################
# 임곗값: 0.1220403181618982
# 오차 행렬
# [[ 72 828]
#  [  3 897]]
# 정확도: 0.5383, 정밀도: 0.5200, 재현율: 0.9967, F1:0.6834, AUC:0.5383
# ###########################################################################
# 임곗값: 0.12210544304499575
# 오차 행렬
# [[ 73 827]
#  [  3 897]]
# 정확도: 0.5389, 정밀도: 0.5203, 재현율: 0.9967, F1:0.6837, AUC:0.5389
# ###########################################################################
# 임곗값: 0.1228530545261546
# 오차 행렬
# [[ 74 826]
#  [  3 897]]
# 정확도: 0.5394, 정밀도: 0.5206, 재현율: 0.9967, F1:0.6839, AUC:0.5394
# ###########################################################################
# 임곗값: 0.12315065298132484
# 오차 행렬
# [[ 75 825]
#  [  3 897]]
# 정확도: 0.5400, 정밀도: 0.5209, 재현율: 0.9967, F1:0.6842, AUC:0.5400
# ###########################################################################
# 임곗값: 0.12390158077495889
# 오차 행렬
# [[ 76 824]
#  [  3 897]]
# 정확도: 0.5406, 정밀도: 0.5212, 재현율: 0.9967, F1:0.6845, AUC:0.5406
# ###########################################################################
# 임곗값: 0.12398502517609492
# 오차 행렬
# [[ 77 823]
#  [  3 897]]
# 정확도: 0.5411, 정밀도: 0.5215, 재현율: 0.9967, F1:0.6847, AUC:0.5411
# ###########################################################################
# 임곗값: 0.12402895397586486
# 오차 행렬
# [[ 78 822]
#  [  3 897]]
# 정확도: 0.5417, 정밀도: 0.5218, 재현율: 0.9967, F1:0.6850, AUC:0.5417
# ###########################################################################
# 임곗값: 0.1241114073926109
# 오차 행렬
# [[ 79 821]
#  [  3 897]]
# 정확도: 0.5422, 정밀도: 0.5221, 재현율: 0.9967, F1:0.6853, AUC:0.5422
# ###########################################################################
# 임곗값: 0.124373563931688
# 오차 행렬
# [[ 80 820]
#  [  3 897]]
# 정확도: 0.5428, 정밀도: 0.5224, 재현율: 0.9967, F1:0.6855, AUC:0.5428
# ###########################################################################
# 임곗값: 0.12456533293772028
# 오차 행렬
# [[ 81 819]
#  [  3 897]]
# 정확도: 0.5433, 정밀도: 0.5227, 재현율: 0.9967, F1:0.6858, AUC:0.5433
# ###########################################################################
# 임곗값: 0.1246669400116131
# 오차 행렬
# [[ 82 818]
#  [  3 897]]
# 정확도: 0.5439, 정밀도: 0.5230, 재현율: 0.9967, F1:0.6860, AUC:0.5439
# ###########################################################################
# 임곗값: 0.12482908108360478
# 오차 행렬
# [[ 83 817]
#  [  3 897]]
# 정확도: 0.5444, 정밀도: 0.5233, 재현율: 0.9967, F1:0.6863, AUC:0.5444
# ###########################################################################
# 임곗값: 0.12502015329417648
# 오차 행렬
# [[ 84 816]
#  [  3 897]]
# 정확도: 0.5450, 정밀도: 0.5236, 재현율: 0.9967, F1:0.6866, AUC:0.5450
# ###########################################################################
# 임곗값: 0.12519918239075303
# 오차 행렬
# [[ 85 815]
#  [  3 897]]
# 정확도: 0.5456, 정밀도: 0.5239, 재현율: 0.9967, F1:0.6868, AUC:0.5456
# ###########################################################################
# 임곗값: 0.12522094296776412
# 오차 행렬
# [[ 86 814]
#  [  3 897]]
# 정확도: 0.5461, 정밀도: 0.5243, 재현율: 0.9967, F1:0.6871, AUC:0.5461
# ###########################################################################
# 임곗값: 0.12546781712359198
# 오차 행렬
# [[ 87 813]
#  [  3 897]]
# 정확도: 0.5467, 정밀도: 0.5246, 재현율: 0.9967, F1:0.6874, AUC:0.5467
# ###########################################################################
# 임곗값: 0.1255448287656662
# 오차 행렬
# [[ 88 812]
#  [  3 897]]
# 정확도: 0.5472, 정밀도: 0.5249, 재현율: 0.9967, F1:0.6876, AUC:0.5472
# ###########################################################################
# 임곗값: 0.12615486860786368
# 오차 행렬
# [[ 89 811]
#  [  3 897]]
# 정확도: 0.5478, 정밀도: 0.5252, 재현율: 0.9967, F1:0.6879, AUC:0.5478
# ###########################################################################
# 임곗값: 0.12626828486557362
# 오차 행렬
# [[ 90 810]
#  [  3 897]]
# 정확도: 0.5483, 정밀도: 0.5255, 재현율: 0.9967, F1:0.6881, AUC:0.5483
# ###########################################################################
# 임곗값: 0.1264177346875702
# 오차 행렬
# [[ 91 809]
#  [  3 897]]
# 정확도: 0.5489, 정밀도: 0.5258, 재현율: 0.9967, F1:0.6884, AUC:0.5489
# ###########################################################################
# 임곗값: 0.1265571394107885
# 오차 행렬
# [[ 92 808]
#  [  3 897]]
# 정확도: 0.5494, 정밀도: 0.5261, 재현율: 0.9967, F1:0.6887, AUC:0.5494
# ###########################################################################
# 임곗값: 0.126812894282873
# 오차 행렬
# [[ 93 807]
#  [  3 897]]
# 정확도: 0.5500, 정밀도: 0.5264, 재현율: 0.9967, F1:0.6889, AUC:0.5500
# ###########################################################################
# 임곗값: 0.12711570905116587
# 오차 행렬
# [[ 94 806]
#  [  3 897]]
# 정확도: 0.5506, 정밀도: 0.5267, 재현율: 0.9967, F1:0.6892, AUC:0.5506
# ###########################################################################
# 임곗값: 0.12732347462421814
# 오차 행렬
# [[ 95 805]
#  [  3 897]]
# 정확도: 0.5511, 정밀도: 0.5270, 재현율: 0.9967, F1:0.6895, AUC:0.5511
# ###########################################################################
# 임곗값: 0.12751612754195013
# 오차 행렬
# [[ 96 804]
#  [  3 897]]
# 정확도: 0.5517, 정밀도: 0.5273, 재현율: 0.9967, F1:0.6897, AUC:0.5517
# ###########################################################################
# 임곗값: 0.12820018081774415
# 오차 행렬
# [[ 97 803]
#  [  3 897]]
# 정확도: 0.5522, 정밀도: 0.5276, 재현율: 0.9967, F1:0.6900, AUC:0.5522
# ###########################################################################
# 임곗값: 0.1289293565812216
# 오차 행렬
# [[ 98 802]
#  [  3 897]]
# 정확도: 0.5528, 정밀도: 0.5280, 재현율: 0.9967, F1:0.6903, AUC:0.5528
# ###########################################################################
# 임곗값: 0.12912463601048765
# 오차 행렬
# [[ 99 801]
#  [  3 897]]
# 정확도: 0.5533, 정밀도: 0.5283, 재현율: 0.9967, F1:0.6905, AUC:0.5533
# ###########################################################################
# 임곗값: 0.1298342846420842
# 오차 행렬
# [[100 800]
#  [  3 897]]
# 정확도: 0.5539, 정밀도: 0.5286, 재현율: 0.9967, F1:0.6908, AUC:0.5539
# ###########################################################################
# 임곗값: 0.13003010873079143
# 오차 행렬
# [[101 799]
#  [  3 897]]
# 정확도: 0.5544, 정밀도: 0.5289, 재현율: 0.9967, F1:0.6911, AUC:0.5544
# ###########################################################################
# 임곗값: 0.13011317225922964
# 오차 행렬
# [[102 798]
#  [  3 897]]
# 정확도: 0.5550, 정밀도: 0.5292, 재현율: 0.9967, F1:0.6913, AUC:0.5550
# ###########################################################################
# 임곗값: 0.13049017515525485
# 오차 행렬
# [[103 797]
#  [  3 897]]
# 정확도: 0.5556, 정밀도: 0.5295, 재현율: 0.9967, F1:0.6916, AUC:0.5556
# ###########################################################################
# 임곗값: 0.130860122931092
# 오차 행렬
# [[104 796]
#  [  3 897]]
# 정확도: 0.5561, 정밀도: 0.5298, 재현율: 0.9967, F1:0.6919, AUC:0.5561
# ###########################################################################
# 임곗값: 0.13091066032281407
# 오차 행렬
# [[105 795]
#  [  3 897]]
# 정확도: 0.5567, 정밀도: 0.5301, 재현율: 0.9967, F1:0.6921, AUC:0.5567
# ###########################################################################
# 임곗값: 0.13109543071576202
# 오차 행렬
# [[106 794]
#  [  3 897]]
# 정확도: 0.5572, 정밀도: 0.5305, 재현율: 0.9967, F1:0.6924, AUC:0.5572
# ###########################################################################
# 임곗값: 0.13122118846129058
# 오차 행렬
# [[107 793]
#  [  3 897]]
# 정확도: 0.5578, 정밀도: 0.5308, 재현율: 0.9967, F1:0.6927, AUC:0.5578
# ###########################################################################
# 임곗값: 0.13148033274396298
# 오차 행렬
# [[108 792]
#  [  3 897]]
# 정확도: 0.5583, 정밀도: 0.5311, 재현율: 0.9967, F1:0.6929, AUC:0.5583
# ###########################################################################
# 임곗값: 0.13191258353892887
# 오차 행렬
# [[109 791]
#  [  3 897]]
# 정확도: 0.5589, 정밀도: 0.5314, 재현율: 0.9967, F1:0.6932, AUC:0.5589
# ###########################################################################
# 임곗값: 0.1319349859990754
# 오차 행렬
# [[110 790]
#  [  3 897]]
# 정확도: 0.5594, 정밀도: 0.5317, 재현율: 0.9967, F1:0.6935, AUC:0.5594
# ###########################################################################
# 임곗값: 0.1321596434312126
# 오차 행렬
# [[111 789]
#  [  3 897]]
# 정확도: 0.5600, 정밀도: 0.5320, 재현율: 0.9967, F1:0.6937, AUC:0.5600
# ###########################################################################
# 임곗값: 0.13251026392921
# 오차 행렬
# [[112 788]
#  [  3 897]]
# 정확도: 0.5606, 정밀도: 0.5323, 재현율: 0.9967, F1:0.6940, AUC:0.5606
# ###########################################################################
# 임곗값: 0.13293057529184862
# 오차 행렬
# [[113 787]
#  [  3 897]]
# 정확도: 0.5611, 정밀도: 0.5327, 재현율: 0.9967, F1:0.6943, AUC:0.5611
# ###########################################################################
# 임곗값: 0.13334862408994527
# 오차 행렬
# [[113 787]
#  [  4 896]]
# 정확도: 0.5606, 정밀도: 0.5324, 재현율: 0.9956, F1:0.6938, AUC:0.5606
# ###########################################################################
# 임곗값: 0.1335241163085956
# 오차 행렬
# [[114 786]
#  [  4 896]]
# 정확도: 0.5611, 정밀도: 0.5327, 재현율: 0.9956, F1:0.6940, AUC:0.5611
# ###########################################################################
# 임곗값: 0.1337857224471246
# 오차 행렬
# [[115 785]
#  [  4 896]]
# 정확도: 0.5617, 정밀도: 0.5330, 재현율: 0.9956, F1:0.6943, AUC:0.5617
# ###########################################################################
# 임곗값: 0.1338324739019916
# 오차 행렬
# [[116 784]
#  [  4 896]]
# 정확도: 0.5622, 정밀도: 0.5333, 재현율: 0.9956, F1:0.6946, AUC:0.5622
# ###########################################################################
# 임곗값: 0.1338841072617818
# 오차 행렬
# [[117 783]
#  [  4 896]]
# 정확도: 0.5628, 정밀도: 0.5337, 재현율: 0.9956, F1:0.6948, AUC:0.5628
# ###########################################################################
# 임곗값: 0.1339398052071223
# 오차 행렬
# [[118 782]
#  [  4 896]]
# 정확도: 0.5633, 정밀도: 0.5340, 재현율: 0.9956, F1:0.6951, AUC:0.5633
# ###########################################################################
# 임곗값: 0.13483659470212295
# 오차 행렬
# [[119 781]
#  [  4 896]]
# 정확도: 0.5639, 정밀도: 0.5343, 재현율: 0.9956, F1:0.6954, AUC:0.5639
# ###########################################################################
# 임곗값: 0.13521964998209263
# 오차 행렬
# [[120 780]
#  [  4 896]]
# 정확도: 0.5644, 정밀도: 0.5346, 재현율: 0.9956, F1:0.6957, AUC:0.5644
# ###########################################################################
# 임곗값: 0.1353751873155043
# 오차 행렬
# [[121 779]
#  [  4 896]]
# 정확도: 0.5650, 정밀도: 0.5349, 재현율: 0.9956, F1:0.6959, AUC:0.5650
# ###########################################################################
# 임곗값: 0.13589516653312234
# 오차 행렬
# [[122 778]
#  [  4 896]]
# 정확도: 0.5656, 정밀도: 0.5352, 재현율: 0.9956, F1:0.6962, AUC:0.5656
# ###########################################################################
# 임곗값: 0.13597419595590587
# 오차 행렬
# [[123 777]
#  [  4 896]]
# 정확도: 0.5661, 정밀도: 0.5356, 재현율: 0.9956, F1:0.6965, AUC:0.5661
# ###########################################################################
# 임곗값: 0.13792177681614828
# 오차 행렬
# [[124 776]
#  [  4 896]]
# 정확도: 0.5667, 정밀도: 0.5359, 재현율: 0.9956, F1:0.6967, AUC:0.5667
# ###########################################################################
# 임곗값: 0.1379771849776796
# 오차 행렬
# [[125 775]
#  [  4 896]]
# 정확도: 0.5672, 정밀도: 0.5362, 재현율: 0.9956, F1:0.6970, AUC:0.5672
# ###########################################################################
# 임곗값: 0.13836165549110643
# 오차 행렬
# [[126 774]
#  [  4 896]]
# 정확도: 0.5678, 정밀도: 0.5365, 재현율: 0.9956, F1:0.6973, AUC:0.5678
# ###########################################################################
# 임곗값: 0.138864723613823
# 오차 행렬
# [[127 773]
#  [  4 896]]
# 정확도: 0.5683, 정밀도: 0.5368, 재현율: 0.9956, F1:0.6975, AUC:0.5683
# ###########################################################################
# 임곗값: 0.13900877962906832
# 오차 행렬
# [[128 772]
#  [  4 896]]
# 정확도: 0.5689, 정밀도: 0.5372, 재현율: 0.9956, F1:0.6978, AUC:0.5689
# ###########################################################################
# 임곗값: 0.13913213964805254
# 오차 행렬
# [[129 771]
#  [  4 896]]
# 정확도: 0.5694, 정밀도: 0.5375, 재현율: 0.9956, F1:0.6981, AUC:0.5694
# ###########################################################################
# 임곗값: 0.13972946915452256
# 오차 행렬
# [[130 770]
#  [  4 896]]
# 정확도: 0.5700, 정밀도: 0.5378, 재현율: 0.9956, F1:0.6984, AUC:0.5700
# ###########################################################################
# 임곗값: 0.13978834616623076
# 오차 행렬
# [[131 769]
#  [  4 896]]
# 정확도: 0.5706, 정밀도: 0.5381, 재현율: 0.9956, F1:0.6986, AUC:0.5706
# ###########################################################################
# 임곗값: 0.13995802735162058
# 오차 행렬
# [[132 768]
#  [  4 896]]
# 정확도: 0.5711, 정밀도: 0.5385, 재현율: 0.9956, F1:0.6989, AUC:0.5711
# ###########################################################################
# 임곗값: 0.1401040966310769
# 오차 행렬
# [[132 768]
#  [  5 895]]
# 정확도: 0.5706, 정밀도: 0.5382, 재현율: 0.9944, F1:0.6984, AUC:0.5706
# ###########################################################################
# 임곗값: 0.14033521485782915
# 오차 행렬
# [[133 767]
#  [  5 895]]
# 정확도: 0.5711, 정밀도: 0.5385, 재현율: 0.9944, F1:0.6987, AUC:0.5711
# ###########################################################################
# 임곗값: 0.14044148284143354
# 오차 행렬
# [[134 766]
#  [  5 895]]
# 정확도: 0.5717, 정밀도: 0.5388, 재현율: 0.9944, F1:0.6989, AUC:0.5717
# ###########################################################################
# 임곗값: 0.14107254416394718
# 오차 행렬
# [[135 765]
#  [  5 895]]
# 정확도: 0.5722, 정밀도: 0.5392, 재현율: 0.9944, F1:0.6992, AUC:0.5722
# ###########################################################################
# 임곗값: 0.14121105029650188
# 오차 행렬
# [[136 764]
#  [  5 895]]
# 정확도: 0.5728, 정밀도: 0.5395, 재현율: 0.9944, F1:0.6995, AUC:0.5728
# ###########################################################################
# 임곗값: 0.142059294224111
# 오차 행렬
# [[136 764]
#  [  6 894]]
# 정확도: 0.5722, 정밀도: 0.5392, 재현율: 0.9933, F1:0.6990, AUC:0.5722
# ###########################################################################
# 임곗값: 0.1423294412451592
# 오차 행렬
# [[137 763]
#  [  6 894]]
# 정확도: 0.5728, 정밀도: 0.5395, 재현율: 0.9933, F1:0.6993, AUC:0.5728
# ###########################################################################
# 임곗값: 0.14276954657569285
# 오차 행렬
# [[138 762]
#  [  6 894]]
# 정확도: 0.5733, 정밀도: 0.5399, 재현율: 0.9933, F1:0.6995, AUC:0.5733
# ###########################################################################
# 임곗값: 0.1428210201895438
# 오차 행렬
# [[139 761]
#  [  6 894]]
# 정확도: 0.5739, 정밀도: 0.5402, 재현율: 0.9933, F1:0.6998, AUC:0.5739
# ###########################################################################
# 임곗값: 0.14283043642604612
# 오차 행렬
# [[140 760]
#  [  6 894]]
# 정확도: 0.5744, 정밀도: 0.5405, 재현율: 0.9933, F1:0.7001, AUC:0.5744
# ###########################################################################
# 임곗값: 0.14283337294544463
# 오차 행렬
# [[141 759]
#  [  6 894]]
# 정확도: 0.5750, 정밀도: 0.5408, 재현율: 0.9933, F1:0.7004, AUC:0.5750
# ###########################################################################
# 임곗값: 0.14292763604482991
# 오차 행렬
# [[142 758]
#  [  6 894]]
# 정확도: 0.5756, 정밀도: 0.5412, 재현율: 0.9933, F1:0.7006, AUC:0.5756
# ###########################################################################
# 임곗값: 0.1432604146646521
# 오차 행렬
# [[143 757]
#  [  6 894]]
# 정확도: 0.5761, 정밀도: 0.5415, 재현율: 0.9933, F1:0.7009, AUC:0.5761
# ###########################################################################
# 임곗값: 0.14353582651043317
# 오차 행렬
# [[144 756]
#  [  6 894]]
# 정확도: 0.5767, 정밀도: 0.5418, 재현율: 0.9933, F1:0.7012, AUC:0.5767
# ###########################################################################
# 임곗값: 0.1439303318221747
# 오차 행렬
# [[145 755]
#  [  6 894]]
# 정확도: 0.5772, 정밀도: 0.5421, 재현율: 0.9933, F1:0.7015, AUC:0.5772
# ###########################################################################
# 임곗값: 0.1440771357811969
# 오차 행렬
# [[146 754]
#  [  6 894]]
# 정확도: 0.5778, 정밀도: 0.5425, 재현율: 0.9933, F1:0.7017, AUC:0.5778
# ###########################################################################
# 임곗값: 0.14472291767142795
# 오차 행렬
# [[147 753]
#  [  6 894]]
# 정확도: 0.5783, 정밀도: 0.5428, 재현율: 0.9933, F1:0.7020, AUC:0.5783
# ###########################################################################
# 임곗값: 0.14592751637065818
# 오차 행렬
# [[148 752]
#  [  6 894]]
# 정확도: 0.5789, 정밀도: 0.5431, 재현율: 0.9933, F1:0.7023, AUC:0.5789
# ###########################################################################
# 임곗값: 0.14637830057605764
# 오차 행렬
# [[149 751]
#  [  6 894]]
# 정확도: 0.5794, 정밀도: 0.5435, 재현율: 0.9933, F1:0.7026, AUC:0.5794
# ###########################################################################
# 임곗값: 0.14652449408231183
# 오차 행렬
# [[150 750]
#  [  6 894]]
# 정확도: 0.5800, 정밀도: 0.5438, 재현율: 0.9933, F1:0.7028, AUC:0.5800
# ###########################################################################
# 임곗값: 0.14694438867311096
# 오차 행렬
# [[151 749]
#  [  6 894]]
# 정확도: 0.5806, 정밀도: 0.5441, 재현율: 0.9933, F1:0.7031, AUC:0.5806
# ###########################################################################
# 임곗값: 0.14715591650265636
# 오차 행렬
# [[152 748]
#  [  6 894]]
# 정확도: 0.5811, 정밀도: 0.5445, 재현율: 0.9933, F1:0.7034, AUC:0.5811
# ###########################################################################
# 임곗값: 0.14741809397642075
# 오차 행렬
# [[153 747]
#  [  6 894]]
# 정확도: 0.5817, 정밀도: 0.5448, 재현율: 0.9933, F1:0.7037, AUC:0.5817
# ###########################################################################
# 임곗값: 0.14801512118400703
# 오차 행렬
# [[154 746]
#  [  6 894]]
# 정확도: 0.5822, 정밀도: 0.5451, 재현율: 0.9933, F1:0.7039, AUC:0.5822
# ###########################################################################
# 임곗값: 0.1483646752150429
# 오차 행렬
# [[155 745]
#  [  6 894]]
# 정확도: 0.5828, 정밀도: 0.5455, 재현율: 0.9933, F1:0.7042, AUC:0.5828
# ###########################################################################
# 임곗값: 0.14841229894399777
# 오차 행렬
# [[156 744]
#  [  6 894]]
# 정확도: 0.5833, 정밀도: 0.5458, 재현율: 0.9933, F1:0.7045, AUC:0.5833
# ###########################################################################
# 임곗값: 0.14854278969453494
# 오차 행렬
# [[157 743]
#  [  6 894]]
# 정확도: 0.5839, 정밀도: 0.5461, 재현율: 0.9933, F1:0.7048, AUC:0.5839
# ###########################################################################
# 임곗값: 0.14873378146341382
# 오차 행렬
# [[158 742]
#  [  6 894]]
# 정확도: 0.5844, 정밀도: 0.5465, 재현율: 0.9933, F1:0.7050, AUC:0.5844
# ###########################################################################
# 임곗값: 0.14911113102825774
# 오차 행렬
# [[159 741]
#  [  6 894]]
# 정확도: 0.5850, 정밀도: 0.5468, 재현율: 0.9933, F1:0.7053, AUC:0.5850
# ###########################################################################
# 임곗값: 0.14916002600634487
# 오차 행렬
# [[160 740]
#  [  6 894]]
# 정확도: 0.5856, 정밀도: 0.5471, 재현율: 0.9933, F1:0.7056, AUC:0.5856
# ###########################################################################
# 임곗값: 0.14918078930438058
# 오차 행렬
# [[161 739]
#  [  6 894]]
# 정확도: 0.5861, 정밀도: 0.5475, 재현율: 0.9933, F1:0.7059, AUC:0.5861
# ###########################################################################
# 임곗값: 0.1496758626349007
# 오차 행렬
# [[162 738]
#  [  6 894]]
# 정확도: 0.5867, 정밀도: 0.5478, 재현율: 0.9933, F1:0.7062, AUC:0.5867
# ###########################################################################
# 임곗값: 0.14991959480632178
# 오차 행렬
# [[163 737]
#  [  6 894]]
# 정확도: 0.5872, 정밀도: 0.5481, 재현율: 0.9933, F1:0.7064, AUC:0.5872
# ###########################################################################
# 임곗값: 0.15001454457671262
# 오차 행렬
# [[164 736]
#  [  6 894]]
# 정확도: 0.5878, 정밀도: 0.5485, 재현율: 0.9933, F1:0.7067, AUC:0.5878
# ###########################################################################
# 임곗값: 0.1500399229528218
# 오차 행렬
# [[165 735]
#  [  6 894]]
# 정확도: 0.5883, 정밀도: 0.5488, 재현율: 0.9933, F1:0.7070, AUC:0.5883
# ###########################################################################
# 임곗값: 0.1500699753664954
# 오차 행렬
# [[165 735]
#  [  7 893]]
# 정확도: 0.5878, 정밀도: 0.5485, 재현율: 0.9922, F1:0.7065, AUC:0.5878
# ###########################################################################
# 임곗값: 0.15007477953653045
# 오차 행렬
# [[166 734]
#  [  7 893]]
# 정확도: 0.5883, 정밀도: 0.5489, 재현율: 0.9922, F1:0.7068, AUC:0.5883
# ###########################################################################
# 임곗값: 0.15051305686337826
# 오차 행렬
# [[167 733]
#  [  7 893]]
# 정확도: 0.5889, 정밀도: 0.5492, 재현율: 0.9922, F1:0.7070, AUC:0.5889
# ###########################################################################
# 임곗값: 0.15077032216345418
# 오차 행렬
# [[168 732]
#  [  7 893]]
# 정확도: 0.5894, 정밀도: 0.5495, 재현율: 0.9922, F1:0.7073, AUC:0.5894
# ###########################################################################
# 임곗값: 0.15111677786849062
# 오차 행렬
# [[169 731]
#  [  7 893]]
# 정확도: 0.5900, 정밀도: 0.5499, 재현율: 0.9922, F1:0.7076, AUC:0.5900
# ###########################################################################
# 임곗값: 0.15139621420856672
# 오차 행렬
# [[170 730]
#  [  7 893]]
# 정확도: 0.5906, 정밀도: 0.5502, 재현율: 0.9922, F1:0.7079, AUC:0.5906
# ###########################################################################
# 임곗값: 0.15170146702246204
# 오차 행렬
# [[171 729]
#  [  7 893]]
# 정확도: 0.5911, 정밀도: 0.5506, 재현율: 0.9922, F1:0.7082, AUC:0.5911
# ###########################################################################
# 임곗값: 0.15176907935184972
# 오차 행렬
# [[171 729]
#  [  8 892]]
# 정확도: 0.5906, 정밀도: 0.5503, 재현율: 0.9911, F1:0.7077, AUC:0.5906
# ###########################################################################
# 임곗값: 0.15214568840383508
# 오차 행렬
# [[171 729]
#  [  9 891]]
# 정확도: 0.5900, 정밀도: 0.5500, 재현율: 0.9900, F1:0.7071, AUC:0.5900
# ###########################################################################
# 임곗값: 0.15248123210708978
# 오차 행렬
# [[172 728]
#  [  9 891]]
# 정확도: 0.5906, 정밀도: 0.5503, 재현율: 0.9900, F1:0.7074, AUC:0.5906
# ###########################################################################
# 임곗값: 0.15253470244889206
# 오차 행렬
# [[173 727]
#  [  9 891]]
# 정확도: 0.5911, 정밀도: 0.5507, 재현율: 0.9900, F1:0.7077, AUC:0.5911
# ###########################################################################
# 임곗값: 0.15265573430354087
# 오차 행렬
# [[174 726]
#  [  9 891]]
# 정확도: 0.5917, 정밀도: 0.5510, 재현율: 0.9900, F1:0.7080, AUC:0.5917
# ###########################################################################
# 임곗값: 0.15287391485469273
# 오차 행렬
# [[175 725]
#  [  9 891]]
# 정확도: 0.5922, 정밀도: 0.5514, 재현율: 0.9900, F1:0.7083, AUC:0.5922
# ###########################################################################
# 임곗값: 0.15331225611400875
# 오차 행렬
# [[176 724]
#  [  9 891]]
# 정확도: 0.5928, 정밀도: 0.5517, 재현율: 0.9900, F1:0.7085, AUC:0.5928
# ###########################################################################
# 임곗값: 0.15334575624513563
# 오차 행렬
# [[177 723]
#  [  9 891]]
# 정확도: 0.5933, 정밀도: 0.5520, 재현율: 0.9900, F1:0.7088, AUC:0.5933
# ###########################################################################
# 임곗값: 0.15359066075406824
# 오차 행렬
# [[178 722]
#  [  9 891]]
# 정확도: 0.5939, 정밀도: 0.5524, 재현율: 0.9900, F1:0.7091, AUC:0.5939
# ###########################################################################
# 임곗값: 0.15362184051857383
# 오차 행렬
# [[179 721]
#  [  9 891]]
# 정확도: 0.5944, 정밀도: 0.5527, 재현율: 0.9900, F1:0.7094, AUC:0.5944
# ###########################################################################
# 임곗값: 0.15427037857977152
# 오차 행렬
# [[180 720]
#  [  9 891]]
# 정확도: 0.5950, 정밀도: 0.5531, 재현율: 0.9900, F1:0.7097, AUC:0.5950
# ###########################################################################
# 임곗값: 0.154664008272876
# 오차 행렬
# [[180 720]
#  [ 10 890]]
# 정확도: 0.5944, 정밀도: 0.5528, 재현율: 0.9889, F1:0.7092, AUC:0.5944
# ###########################################################################
# 임곗값: 0.15559695279752728
# 오차 행렬
# [[181 719]
#  [ 10 890]]
# 정확도: 0.5950, 정밀도: 0.5531, 재현율: 0.9889, F1:0.7094, AUC:0.5950
# ###########################################################################
# 임곗값: 0.15589199484049693
# 오차 행렬
# [[182 718]
#  [ 10 890]]
# 정확도: 0.5956, 정밀도: 0.5535, 재현율: 0.9889, F1:0.7097, AUC:0.5956
# ###########################################################################
# 임곗값: 0.15635836753320664
# 오차 행렬
# [[183 717]
#  [ 10 890]]
# 정확도: 0.5961, 정밀도: 0.5538, 재현율: 0.9889, F1:0.7100, AUC:0.5961
# ###########################################################################
# 임곗값: 0.15668055833837247
# 오차 행렬
# [[184 716]
#  [ 10 890]]
# 정확도: 0.5967, 정밀도: 0.5542, 재현율: 0.9889, F1:0.7103, AUC:0.5967
# ###########################################################################
# 임곗값: 0.15722345978105387
# 오차 행렬
# [[185 715]
#  [ 10 890]]
# 정확도: 0.5972, 정밀도: 0.5545, 재현율: 0.9889, F1:0.7106, AUC:0.5972
# ###########################################################################
# 임곗값: 0.15723483253747608
# 오차 행렬
# [[186 714]
#  [ 10 890]]
# 정확도: 0.5978, 정밀도: 0.5549, 재현율: 0.9889, F1:0.7109, AUC:0.5978
# ###########################################################################
# 임곗값: 0.15786514220876108
# 오차 행렬
# [[187 713]
#  [ 10 890]]
# 정확도: 0.5983, 정밀도: 0.5552, 재현율: 0.9889, F1:0.7111, AUC:0.5983
# ###########################################################################
# 임곗값: 0.15823752768846722
# 오차 행렬
# [[188 712]
#  [ 10 890]]
# 정확도: 0.5989, 정밀도: 0.5556, 재현율: 0.9889, F1:0.7114, AUC:0.5989
# ###########################################################################
# 임곗값: 0.15823914328900096
# 오차 행렬
# [[189 711]
#  [ 10 890]]
# 정확도: 0.5994, 정밀도: 0.5559, 재현율: 0.9889, F1:0.7117, AUC:0.5994
# ###########################################################################
# 임곗값: 0.15834200088661046
# 오차 행렬
# [[190 710]
#  [ 10 890]]
# 정확도: 0.6000, 정밀도: 0.5563, 재현율: 0.9889, F1:0.7120, AUC:0.6000
# ###########################################################################
# 임곗값: 0.15845074906513332
# 오차 행렬
# [[191 709]
#  [ 10 890]]
# 정확도: 0.6006, 정밀도: 0.5566, 재현율: 0.9889, F1:0.7123, AUC:0.6006
# ###########################################################################
# 임곗값: 0.15855108735099738
# 오차 행렬
# [[192 708]
#  [ 10 890]]
# 정확도: 0.6011, 정밀도: 0.5569, 재현율: 0.9889, F1:0.7126, AUC:0.6011
# ###########################################################################
# 임곗값: 0.1587354562525954
# 오차 행렬
# [[193 707]
#  [ 10 890]]
# 정확도: 0.6017, 정밀도: 0.5573, 재현율: 0.9889, F1:0.7129, AUC:0.6017
# ###########################################################################
# 임곗값: 0.15943981432514853
# 오차 행렬
# [[194 706]
#  [ 10 890]]
# 정확도: 0.6022, 정밀도: 0.5576, 재현율: 0.9889, F1:0.7131, AUC:0.6022
# ###########################################################################
# 임곗값: 0.15994461106463775
# 오차 행렬
# [[194 706]
#  [ 11 889]]
# 정확도: 0.6017, 정밀도: 0.5574, 재현율: 0.9878, F1:0.7126, AUC:0.6017
# ###########################################################################
# 임곗값: 0.160035573771118
# 오차 행렬
# [[195 705]
#  [ 11 889]]
# 정확도: 0.6022, 정밀도: 0.5577, 재현율: 0.9878, F1:0.7129, AUC:0.6022
# ###########################################################################
# 임곗값: 0.1600926502324282
# 오차 행렬
# [[196 704]
#  [ 11 889]]
# 정확도: 0.6028, 정밀도: 0.5581, 재현율: 0.9878, F1:0.7132, AUC:0.6028
# ###########################################################################
# 임곗값: 0.16022476267906235
# 오차 행렬
# [[197 703]
#  [ 11 889]]
# 정확도: 0.6033, 정밀도: 0.5584, 재현율: 0.9878, F1:0.7135, AUC:0.6033
# ###########################################################################
# 임곗값: 0.16074337738989616
# 오차 행렬
# [[197 703]
#  [ 12 888]]
# 정확도: 0.6028, 정밀도: 0.5581, 재현율: 0.9867, F1:0.7130, AUC:0.6028
# ###########################################################################
# 임곗값: 0.16075651343839567
# 오차 행렬
# [[198 702]
#  [ 12 888]]
# 정확도: 0.6033, 정밀도: 0.5585, 재현율: 0.9867, F1:0.7133, AUC:0.6033
# ###########################################################################
# 임곗값: 0.16077099152976385
# 오차 행렬
# [[199 701]
#  [ 12 888]]
# 정확도: 0.6039, 정밀도: 0.5588, 재현율: 0.9867, F1:0.7135, AUC:0.6039
# ###########################################################################
# 임곗값: 0.16081116726893352
# 오차 행렬
# [[200 700]
#  [ 12 888]]
# 정확도: 0.6044, 정밀도: 0.5592, 재현율: 0.9867, F1:0.7138, AUC:0.6044
# ###########################################################################
# 임곗값: 0.1609199955857051
# 오차 행렬
# [[201 699]
#  [ 12 888]]
# 정확도: 0.6050, 정밀도: 0.5595, 재현율: 0.9867, F1:0.7141, AUC:0.6050
# ###########################################################################
# 임곗값: 0.16100201594003516
# 오차 행렬
# [[202 698]
#  [ 12 888]]
# 정확도: 0.6056, 정밀도: 0.5599, 재현율: 0.9867, F1:0.7144, AUC:0.6056
# ###########################################################################
# 임곗값: 0.1610709691168809
# 오차 행렬
# [[203 697]
#  [ 12 888]]
# 정확도: 0.6061, 정밀도: 0.5603, 재현율: 0.9867, F1:0.7147, AUC:0.6061
# ###########################################################################
# 임곗값: 0.1611697280033941
# 오차 행렬
# [[204 696]
#  [ 12 888]]
# 정확도: 0.6067, 정밀도: 0.5606, 재현율: 0.9867, F1:0.7150, AUC:0.6067
# ###########################################################################
# 임곗값: 0.1611752613758757
# 오차 행렬
# [[205 695]
#  [ 12 888]]
# 정확도: 0.6072, 정밀도: 0.5610, 재현율: 0.9867, F1:0.7153, AUC:0.6072
# ###########################################################################
# 임곗값: 0.16151158610659294
# 오차 행렬
# [[205 695]
#  [ 13 887]]
# 정확도: 0.6067, 정밀도: 0.5607, 재현율: 0.9856, F1:0.7147, AUC:0.6067
# ###########################################################################
# 임곗값: 0.1619916061960576
# 오차 행렬
# [[206 694]
#  [ 13 887]]
# 정확도: 0.6072, 정밀도: 0.5610, 재현율: 0.9856, F1:0.7150, AUC:0.6072
# ###########################################################################
# 임곗값: 0.16248698324243896
# 오차 행렬
# [[207 693]
#  [ 13 887]]
# 정확도: 0.6078, 정밀도: 0.5614, 재현율: 0.9856, F1:0.7153, AUC:0.6078
# ###########################################################################
# 임곗값: 0.16248980722866332
# 오차 행렬
# [[208 692]
#  [ 13 887]]
# 정확도: 0.6083, 정밀도: 0.5617, 재현율: 0.9856, F1:0.7156, AUC:0.6083
# ###########################################################################
# 임곗값: 0.16258243764695346
# 오차 행렬
# [[209 691]
#  [ 13 887]]
# 정확도: 0.6089, 정밀도: 0.5621, 재현율: 0.9856, F1:0.7159, AUC:0.6089
# ###########################################################################
# 임곗값: 0.1626334916243758
# 오차 행렬
# [[210 690]
#  [ 13 887]]
# 정확도: 0.6094, 정밀도: 0.5625, 재현율: 0.9856, F1:0.7162, AUC:0.6094
# ###########################################################################
# 임곗값: 0.16336134833881338
# 오차 행렬
# [[211 689]
#  [ 13 887]]
# 정확도: 0.6100, 정밀도: 0.5628, 재현율: 0.9856, F1:0.7165, AUC:0.6100
# ###########################################################################
# 임곗값: 0.16351820378574214
# 오차 행렬
# [[212 688]
#  [ 13 887]]
# 정확도: 0.6106, 정밀도: 0.5632, 재현율: 0.9856, F1:0.7168, AUC:0.6106
# ###########################################################################
# 임곗값: 0.16420118589778618
# 오차 행렬
# [[213 687]
#  [ 13 887]]
# 정확도: 0.6111, 정밀도: 0.5635, 재현율: 0.9856, F1:0.7171, AUC:0.6111
# ###########################################################################
# 임곗값: 0.1642766759614243
# 오차 행렬
# [[213 687]
#  [ 14 886]]
# 정확도: 0.6106, 정밀도: 0.5633, 재현율: 0.9844, F1:0.7165, AUC:0.6106
# ###########################################################################
# 임곗값: 0.16472144759983773
# 오차 행렬
# [[213 687]
#  [ 15 885]]
# 정확도: 0.6100, 정밀도: 0.5630, 재현율: 0.9833, F1:0.7160, AUC:0.6100
# ###########################################################################
# 임곗값: 0.1650020303720654
# 오차 행렬
# [[214 686]
#  [ 15 885]]
# 정확도: 0.6106, 정밀도: 0.5633, 재현율: 0.9833, F1:0.7163, AUC:0.6106
# ###########################################################################
# 임곗값: 0.1658037405347035
# 오차 행렬
# [[215 685]
#  [ 15 885]]
# 정확도: 0.6111, 정밀도: 0.5637, 재현율: 0.9833, F1:0.7166, AUC:0.6111
# ###########################################################################
# 임곗값: 0.16583741259938856
# 오차 행렬
# [[216 684]
#  [ 15 885]]
# 정확도: 0.6117, 정밀도: 0.5641, 재현율: 0.9833, F1:0.7169, AUC:0.6117
# ###########################################################################
# 임곗값: 0.16733991463153264
# 오차 행렬
# [[217 683]
#  [ 15 885]]
# 정확도: 0.6122, 정밀도: 0.5644, 재현율: 0.9833, F1:0.7172, AUC:0.6122
# ###########################################################################
# 임곗값: 0.16776884249750862
# 오차 행렬
# [[218 682]
#  [ 15 885]]
# 정확도: 0.6128, 정밀도: 0.5648, 재현율: 0.9833, F1:0.7175, AUC:0.6128
# ###########################################################################
# 임곗값: 0.16842496088029565
# 오차 행렬
# [[219 681]
#  [ 15 885]]
# 정확도: 0.6133, 정밀도: 0.5651, 재현율: 0.9833, F1:0.7178, AUC:0.6133
# ###########################################################################
# 임곗값: 0.16850346973629457
# 오차 행렬
# [[220 680]
#  [ 15 885]]
# 정확도: 0.6139, 정밀도: 0.5655, 재현율: 0.9833, F1:0.7181, AUC:0.6139
# ###########################################################################
# 임곗값: 0.16892092350151763
# 오차 행렬
# [[221 679]
#  [ 15 885]]
# 정확도: 0.6144, 정밀도: 0.5659, 재현율: 0.9833, F1:0.7183, AUC:0.6144
# ###########################################################################
# 임곗값: 0.1689383219454788
# 오차 행렬
# [[222 678]
#  [ 15 885]]
# 정확도: 0.6150, 정밀도: 0.5662, 재현율: 0.9833, F1:0.7186, AUC:0.6150
# ###########################################################################
# 임곗값: 0.16895334509229243
# 오차 행렬
# [[223 677]
#  [ 15 885]]
# 정확도: 0.6156, 정밀도: 0.5666, 재현율: 0.9833, F1:0.7189, AUC:0.6156
# ###########################################################################
# 임곗값: 0.16912172800599795
# 오차 행렬
# [[224 676]
#  [ 15 885]]
# 정확도: 0.6161, 정밀도: 0.5669, 재현율: 0.9833, F1:0.7192, AUC:0.6161
# ###########################################################################
# 임곗값: 0.1691688112816847
# 오차 행렬
# [[225 675]
#  [ 15 885]]
# 정확도: 0.6167, 정밀도: 0.5673, 재현율: 0.9833, F1:0.7195, AUC:0.6167
# ###########################################################################
# 임곗값: 0.1692236086673082
# 오차 행렬
# [[226 674]
#  [ 15 885]]
# 정확도: 0.6172, 정밀도: 0.5677, 재현율: 0.9833, F1:0.7198, AUC:0.6172
# ###########################################################################
# 임곗값: 0.16975749421010827
# 오차 행렬
# [[226 674]
#  [ 16 884]]
# 정확도: 0.6167, 정밀도: 0.5674, 재현율: 0.9822, F1:0.7193, AUC:0.6167
# ###########################################################################
# 임곗값: 0.16976078627504157
# 오차 행렬
# [[227 673]
#  [ 16 884]]
# 정확도: 0.6172, 정밀도: 0.5678, 재현율: 0.9822, F1:0.7196, AUC:0.6172
# ###########################################################################
# 임곗값: 0.17006907446582592
# 오차 행렬
# [[228 672]
#  [ 16 884]]
# 정확도: 0.6178, 정밀도: 0.5681, 재현율: 0.9822, F1:0.7199, AUC:0.6178
# ###########################################################################
# 임곗값: 0.170688220244941
# 오차 행렬
# [[229 671]
#  [ 16 884]]
# 정확도: 0.6183, 정밀도: 0.5685, 재현율: 0.9822, F1:0.7202, AUC:0.6183
# ###########################################################################
# 임곗값: 0.17137661490693595
# 오차 행렬
# [[230 670]
#  [ 16 884]]
# 정확도: 0.6189, 정밀도: 0.5689, 재현율: 0.9822, F1:0.7205, AUC:0.6189
# ###########################################################################
# 임곗값: 0.17142435045769625
# 오차 행렬
# [[231 669]
#  [ 16 884]]
# 정확도: 0.6194, 정밀도: 0.5692, 재현율: 0.9822, F1:0.7208, AUC:0.6194
# ###########################################################################
# 임곗값: 0.17167585615492498
# 오차 행렬
# [[232 668]
#  [ 16 884]]
# 정확도: 0.6200, 정밀도: 0.5696, 재현율: 0.9822, F1:0.7210, AUC:0.6200
# ###########################################################################
# 임곗값: 0.1717761784470168
# 오차 행렬
# [[233 667]
#  [ 16 884]]
# 정확도: 0.6206, 정밀도: 0.5700, 재현율: 0.9822, F1:0.7213, AUC:0.6206
# ###########################################################################
# 임곗값: 0.17202980158430126
# 오차 행렬
# [[234 666]
#  [ 16 884]]
# 정확도: 0.6211, 정밀도: 0.5703, 재현율: 0.9822, F1:0.7216, AUC:0.6211
# ###########################################################################
# 임곗값: 0.17208099304562424
# 오차 행렬
# [[235 665]
#  [ 16 884]]
# 정확도: 0.6217, 정밀도: 0.5707, 재현율: 0.9822, F1:0.7219, AUC:0.6217
# ###########################################################################
# 임곗값: 0.17388022414323845
# 오차 행렬
# [[236 664]
#  [ 16 884]]
# 정확도: 0.6222, 정밀도: 0.5711, 재현율: 0.9822, F1:0.7222, AUC:0.6222
# ...
# ###########################################################################
# 임곗값: 0.8318178209877441
# 오차 행렬
# [[895   5]
#  [824  76]]
# 정확도: 0.5394, 정밀도: 0.9383, 재현율: 0.0844, F1:0.1549, AUC:0.5394
# ###########################################################################
# 임곗값: 0.8324551161085728
# 오차 행렬
# [[895   5]
#  [825  75]]
# 정확도: 0.5389, 정밀도: 0.9375, 재현율: 0.0833, F1:0.1531, AUC:0.5389
# ###########################################################################
# 임곗값: 0.8326962480908593
# 오차 행렬
# [[895   5]
#  [826  74]]
# 정확도: 0.5383, 정밀도: 0.9367, 재현율: 0.0822, F1:0.1512, AUC:0.5383
# ###########################################################################
# 임곗값: 0.8331185482240202
# 오차 행렬
# [[895   5]
#  [827  73]]
# 정확도: 0.5378, 정밀도: 0.9359, 재현율: 0.0811, F1:0.1493, AUC:0.5378
# ###########################################################################
# 임곗값: 0.8340100986905545
# 오차 행렬
# [[895   5]
#  [828  72]]
# 정확도: 0.5372, 정밀도: 0.9351, 재현율: 0.0800, F1:0.1474, AUC:0.5372
# ###########################################################################
# 임곗값: 0.8341690411032728
# 오차 행렬
# [[895   5]
#  [829  71]]
# 정확도: 0.5367, 정밀도: 0.9342, 재현율: 0.0789, F1:0.1455, AUC:0.5367
# ###########################################################################
# 임곗값: 0.8348828524413859
# 오차 행렬
# [[895   5]
#  [830  70]]
# 정확도: 0.5361, 정밀도: 0.9333, 재현율: 0.0778, F1:0.1436, AUC:0.5361
# ###########################################################################
# 임곗값: 0.8361512548779797
# 오차 행렬
# [[896   4]
#  [830  70]]
# 정확도: 0.5367, 정밀도: 0.9459, 재현율: 0.0778, F1:0.1437, AUC:0.5367
# ###########################################################################
# 임곗값: 0.836455633728598
# 오차 행렬
# [[896   4]
#  [831  69]]
# 정확도: 0.5361, 정밀도: 0.9452, 재현율: 0.0767, F1:0.1418, AUC:0.5361
# ###########################################################################
# 임곗값: 0.8369842384438974
# 오차 행렬
# [[896   4]
#  [832  68]]
# 정확도: 0.5356, 정밀도: 0.9444, 재현율: 0.0756, F1:0.1399, AUC:0.5356
# ###########################################################################
# 임곗값: 0.837090131717694
# 오차 행렬
# [[897   3]
#  [832  68]]
# 정확도: 0.5361, 정밀도: 0.9577, 재현율: 0.0756, F1:0.1401, AUC:0.5361
# ###########################################################################
# 임곗값: 0.8375216188063074
# 오차 행렬
# [[897   3]
#  [833  67]]
# 정확도: 0.5356, 정밀도: 0.9571, 재현율: 0.0744, F1:0.1381, AUC:0.5356
# ###########################################################################
# 임곗값: 0.8378897158765527
# 오차 행렬
# [[897   3]
#  [834  66]]
# 정확도: 0.5350, 정밀도: 0.9565, 재현율: 0.0733, F1:0.1362, AUC:0.5350
# ###########################################################################
# 임곗값: 0.8384599191456168
# 오차 행렬
# [[897   3]
#  [835  65]]
# 정확도: 0.5344, 정밀도: 0.9559, 재현율: 0.0722, F1:0.1343, AUC:0.5344
# ###########################################################################
# 임곗값: 0.8388615679443125
# 오차 행렬
# [[897   3]
#  [836  64]]
# 정확도: 0.5339, 정밀도: 0.9552, 재현율: 0.0711, F1:0.1324, AUC:0.5339
# ###########################################################################
# 임곗값: 0.8391099939286688
# 오차 행렬
# [[897   3]
#  [837  63]]
# 정확도: 0.5333, 정밀도: 0.9545, 재현율: 0.0700, F1:0.1304, AUC:0.5333
# ###########################################################################
# 임곗값: 0.839826336527264
# 오차 행렬
# [[897   3]
#  [838  62]]
# 정확도: 0.5328, 정밀도: 0.9538, 재현율: 0.0689, F1:0.1285, AUC:0.5328
# ###########################################################################
# 임곗값: 0.8398750412611129
# 오차 행렬
# [[897   3]
#  [839  61]]
# 정확도: 0.5322, 정밀도: 0.9531, 재현율: 0.0678, F1:0.1266, AUC:0.5322
# ###########################################################################
# 임곗값: 0.8401277145165953
# 오차 행렬
# [[897   3]
#  [840  60]]
# 정확도: 0.5317, 정밀도: 0.9524, 재현율: 0.0667, F1:0.1246, AUC:0.5317
# ###########################################################################
# 임곗값: 0.8401570075744322
# 오차 행렬
# [[897   3]
#  [841  59]]
# 정확도: 0.5311, 정밀도: 0.9516, 재현율: 0.0656, F1:0.1227, AUC:0.5311
# ###########################################################################
# 임곗값: 0.840360924997313
# 오차 행렬
# [[897   3]
#  [842  58]]
# 정확도: 0.5306, 정밀도: 0.9508, 재현율: 0.0644, F1:0.1207, AUC:0.5306
# ###########################################################################
# 임곗값: 0.8406390558944468
# 오차 행렬
# [[897   3]
#  [843  57]]
# 정확도: 0.5300, 정밀도: 0.9500, 재현율: 0.0633, F1:0.1188, AUC:0.5300
# ###########################################################################
# 임곗값: 0.8412056038615263
# 오차 행렬
# [[897   3]
#  [844  56]]
# 정확도: 0.5294, 정밀도: 0.9492, 재현율: 0.0622, F1:0.1168, AUC:0.5294
# ###########################################################################
# 임곗값: 0.8415571776789758
# 오차 행렬
# [[897   3]
#  [845  55]]
# 정확도: 0.5289, 정밀도: 0.9483, 재현율: 0.0611, F1:0.1148, AUC:0.5289
# ###########################################################################
# 임곗값: 0.8426543114875513
# 오차 행렬
# [[897   3]
#  [846  54]]
# 정확도: 0.5283, 정밀도: 0.9474, 재현율: 0.0600, F1:0.1129, AUC:0.5283
# ###########################################################################
# 임곗값: 0.8430449131552369
# 오차 행렬
# [[897   3]
#  [847  53]]
# 정확도: 0.5278, 정밀도: 0.9464, 재현율: 0.0589, F1:0.1109, AUC:0.5278
# ###########################################################################
# 임곗값: 0.8441747255799005
# 오차 행렬
# [[897   3]
#  [848  52]]
# 정확도: 0.5272, 정밀도: 0.9455, 재현율: 0.0578, F1:0.1089, AUC:0.5272
# ###########################################################################
# 임곗값: 0.8444125469687087
# 오차 행렬
# [[897   3]
#  [849  51]]
# 정확도: 0.5267, 정밀도: 0.9444, 재현율: 0.0567, F1:0.1069, AUC:0.5267
# ###########################################################################
# 임곗값: 0.8445614425273017
# 오차 행렬
# [[897   3]
#  [850  50]]
# 정확도: 0.5261, 정밀도: 0.9434, 재현율: 0.0556, F1:0.1049, AUC:0.5261
# ###########################################################################
# 임곗값: 0.8449874744307675
# 오차 행렬
# [[897   3]
#  [851  49]]
# 정확도: 0.5256, 정밀도: 0.9423, 재현율: 0.0544, F1:0.1029, AUC:0.5256
# ###########################################################################
# 임곗값: 0.8471377190315614
# 오차 행렬
# [[897   3]
#  [852  48]]
# 정확도: 0.5250, 정밀도: 0.9412, 재현율: 0.0533, F1:0.1009, AUC:0.5250
# ###########################################################################
# 임곗값: 0.8476130408052867
# 오차 행렬
# [[897   3]
#  [853  47]]
# 정확도: 0.5244, 정밀도: 0.9400, 재현율: 0.0522, F1:0.0989, AUC:0.5244
# ###########################################################################
# 임곗값: 0.8479412249633411
# 오차 행렬
# [[897   3]
#  [854  46]]
# 정확도: 0.5239, 정밀도: 0.9388, 재현율: 0.0511, F1:0.0969, AUC:0.5239
# ###########################################################################
# 임곗값: 0.8487822214528257
# 오차 행렬
# [[898   2]
#  [854  46]]
# 정확도: 0.5244, 정밀도: 0.9583, 재현율: 0.0511, F1:0.0970, AUC:0.5244
# ###########################################################################
# 임곗값: 0.8493282808012347
# 오차 행렬
# [[898   2]
#  [855  45]]
# 정확도: 0.5239, 정밀도: 0.9574, 재현율: 0.0500, F1:0.0950, AUC:0.5239
# ###########################################################################
# 임곗값: 0.8496528037866508
# 오차 행렬
# [[898   2]
#  [856  44]]
# 정확도: 0.5233, 정밀도: 0.9565, 재현율: 0.0489, F1:0.0930, AUC:0.5233
# ###########################################################################
# 임곗값: 0.8500674723314132
# 오차 행렬
# [[898   2]
#  [857  43]]
# 정확도: 0.5228, 정밀도: 0.9556, 재현율: 0.0478, F1:0.0910, AUC:0.5228
# ###########################################################################
# 임곗값: 0.8511793326469612
# 오차 행렬
# [[898   2]
#  [858  42]]
# 정확도: 0.5222, 정밀도: 0.9545, 재현율: 0.0467, F1:0.0890, AUC:0.5222
# ###########################################################################
# 임곗값: 0.852042818507267
# 오차 행렬
# [[899   1]
#  [858  42]]
# 정확도: 0.5228, 정밀도: 0.9767, 재현율: 0.0467, F1:0.0891, AUC:0.5228
# ###########################################################################
# 임곗값: 0.8526278216723183
# 오차 행렬
# [[899   1]
#  [859  41]]
# 정확도: 0.5222, 정밀도: 0.9762, 재현율: 0.0456, F1:0.0870, AUC:0.5222
# ###########################################################################
# 임곗값: 0.8527133926861875
# 오차 행렬
# [[899   1]
#  [860  40]]
# 정확도: 0.5217, 정밀도: 0.9756, 재현율: 0.0444, F1:0.0850, AUC:0.5217
# ###########################################################################
# 임곗값: 0.8553722891697025
# 오차 행렬
# [[899   1]
#  [861  39]]
# 정확도: 0.5211, 정밀도: 0.9750, 재현율: 0.0433, F1:0.0830, AUC:0.5211
# ###########################################################################
# 임곗값: 0.8562707947465017
# 오차 행렬
# [[899   1]
#  [862  38]]
# 정확도: 0.5206, 정밀도: 0.9744, 재현율: 0.0422, F1:0.0809, AUC:0.5206
# ###########################################################################
# 임곗값: 0.8583001306334778
# 오차 행렬
# [[899   1]
#  [863  37]]
# 정확도: 0.5200, 정밀도: 0.9737, 재현율: 0.0411, F1:0.0789, AUC:0.5200
# ###########################################################################
# 임곗값: 0.8590416447283736
# 오차 행렬
# [[899   1]
#  [864  36]]
# 정확도: 0.5194, 정밀도: 0.9730, 재현율: 0.0400, F1:0.0768, AUC:0.5194
# ###########################################################################
# 임곗값: 0.8609882154743689
# 오차 행렬
# [[899   1]
#  [865  35]]
# 정확도: 0.5189, 정밀도: 0.9722, 재현율: 0.0389, F1:0.0748, AUC:0.5189
# ###########################################################################
# 임곗값: 0.8611734275709273
# 오차 행렬
# [[899   1]
#  [866  34]]
# 정확도: 0.5183, 정밀도: 0.9714, 재현율: 0.0378, F1:0.0727, AUC:0.5183
# ###########################################################################
# 임곗값: 0.8613463950488806
# 오차 행렬
# [[899   1]
#  [867  33]]
# 정확도: 0.5178, 정밀도: 0.9706, 재현율: 0.0367, F1:0.0707, AUC:0.5178
# ###########################################################################
# 임곗값: 0.8618359380960592
# 오차 행렬
# [[899   1]
#  [868  32]]
# 정확도: 0.5172, 정밀도: 0.9697, 재현율: 0.0356, F1:0.0686, AUC:0.5172
# ###########################################################################
# 임곗값: 0.8618879443025671
# 오차 행렬
# [[899   1]
#  [869  31]]
# 정확도: 0.5167, 정밀도: 0.9688, 재현율: 0.0344, F1:0.0665, AUC:0.5167
# ###########################################################################
# 임곗값: 0.8630537333036
# 오차 행렬
# [[899   1]
#  [870  30]]
# 정확도: 0.5161, 정밀도: 0.9677, 재현율: 0.0333, F1:0.0644, AUC:0.5161
# ###########################################################################
# 임곗값: 0.8640494001143944
# 오차 행렬
# [[899   1]
#  [871  29]]
# 정확도: 0.5156, 정밀도: 0.9667, 재현율: 0.0322, F1:0.0624, AUC:0.5156
# ###########################################################################
# 임곗값: 0.864227464956089
# 오차 행렬
# [[899   1]
#  [872  28]]
# 정확도: 0.5150, 정밀도: 0.9655, 재현율: 0.0311, F1:0.0603, AUC:0.5150
# ###########################################################################
# 임곗값: 0.8648464295563666
# 오차 행렬
# [[899   1]
#  [873  27]]
# 정확도: 0.5144, 정밀도: 0.9643, 재현율: 0.0300, F1:0.0582, AUC:0.5144
# ###########################################################################
# 임곗값: 0.8666620165337774
# 오차 행렬
# [[899   1]
#  [874  26]]
# 정확도: 0.5139, 정밀도: 0.9630, 재현율: 0.0289, F1:0.0561, AUC:0.5139
# ###########################################################################
# 임곗값: 0.8678527425892518
# 오차 행렬
# [[899   1]
#  [875  25]]
# 정확도: 0.5133, 정밀도: 0.9615, 재현율: 0.0278, F1:0.0540, AUC:0.5133
# ###########################################################################
# 임곗값: 0.8689713478909319
# 오차 행렬
# [[899   1]
#  [876  24]]
# 정확도: 0.5128, 정밀도: 0.9600, 재현율: 0.0267, F1:0.0519, AUC:0.5128
# ###########################################################################
# 임곗값: 0.8690432600207534
# 오차 행렬
# [[899   1]
#  [877  23]]
# 정확도: 0.5122, 정밀도: 0.9583, 재현율: 0.0256, F1:0.0498, AUC:0.5122
# ###########################################################################
# 임곗값: 0.8697320083191739
# 오차 행렬
# [[899   1]
#  [878  22]]
# 정확도: 0.5117, 정밀도: 0.9565, 재현율: 0.0244, F1:0.0477, AUC:0.5117
# ###########################################################################
# 임곗값: 0.8701839074014279
# 오차 행렬
# [[899   1]
#  [879  21]]
# 정확도: 0.5111, 정밀도: 0.9545, 재현율: 0.0233, F1:0.0456, AUC:0.5111
# ###########################################################################
# 임곗값: 0.8712385270549352
# 오차 행렬
# [[899   1]
#  [880  20]]
# 정확도: 0.5106, 정밀도: 0.9524, 재현율: 0.0222, F1:0.0434, AUC:0.5106
# ###########################################################################
# 임곗값: 0.8712407210078683
# 오차 행렬
# [[899   1]
#  [881  19]]
# 정확도: 0.5100, 정밀도: 0.9500, 재현율: 0.0211, F1:0.0413, AUC:0.5100
# ###########################################################################
# 임곗값: 0.8718898115083953
# 오차 행렬
# [[899   1]
#  [882  18]]
# 정확도: 0.5094, 정밀도: 0.9474, 재현율: 0.0200, F1:0.0392, AUC:0.5094
# ###########################################################################
# 임곗값: 0.8734701153668547
# 오차 행렬
# [[899   1]
#  [883  17]]
# 정확도: 0.5089, 정밀도: 0.9444, 재현율: 0.0189, F1:0.0370, AUC:0.5089
# ###########################################################################
# 임곗값: 0.8745300018467834
# 오차 행렬
# [[899   1]
#  [884  16]]
# 정확도: 0.5083, 정밀도: 0.9412, 재현율: 0.0178, F1:0.0349, AUC:0.5083
# ###########################################################################
# 임곗값: 0.8758174178916442
# 오차 행렬
# [[899   1]
#  [885  15]]
# 정확도: 0.5078, 정밀도: 0.9375, 재현율: 0.0167, F1:0.0328, AUC:0.5078
# ###########################################################################
# 임곗값: 0.8767426519773287
# 오차 행렬
# [[899   1]
#  [886  14]]
# 정확도: 0.5072, 정밀도: 0.9333, 재현율: 0.0156, F1:0.0306, AUC:0.5072
# ###########################################################################
# 임곗값: 0.8774289335095365
# 오차 행렬
# [[899   1]
#  [887  13]]
# 정확도: 0.5067, 정밀도: 0.9286, 재현율: 0.0144, F1:0.0284, AUC:0.5067
# ###########################################################################
# 임곗값: 0.8779762640793356
# 오차 행렬
# [[899   1]
#  [888  12]]
# 정확도: 0.5061, 정밀도: 0.9231, 재현율: 0.0133, F1:0.0263, AUC:0.5061
# ###########################################################################
# 임곗값: 0.8781757548691289
# 오차 행렬
# [[899   1]
#  [889  11]]
# 정확도: 0.5056, 정밀도: 0.9167, 재현율: 0.0122, F1:0.0241, AUC:0.5056
# ###########################################################################
# 임곗값: 0.8793112139423219
# 오차 행렬
# [[899   1]
#  [890  10]]
# 정확도: 0.5050, 정밀도: 0.9091, 재현율: 0.0111, F1:0.0220, AUC:0.5050
# ###########################################################################
# 임곗값: 0.8808500255079587
# 오차 행렬
# [[899   1]
#  [891   9]]
# 정확도: 0.5044, 정밀도: 0.9000, 재현율: 0.0100, F1:0.0198, AUC:0.5044
# ###########################################################################
# 임곗값: 0.8819133583169869
# 오차 행렬
# [[899   1]
#  [892   8]]
# 정확도: 0.5039, 정밀도: 0.8889, 재현율: 0.0089, F1:0.0176, AUC:0.5039
# ###########################################################################
# 임곗값: 0.8831668785939027
# 오차 행렬
# [[899   1]
#  [893   7]]
# 정확도: 0.5033, 정밀도: 0.8750, 재현율: 0.0078, F1:0.0154, AUC:0.5033
# ###########################################################################
# 임곗값: 0.8895158171536879
# 오차 행렬
# [[899   1]
#  [894   6]]
# 정확도: 0.5028, 정밀도: 0.8571, 재현율: 0.0067, F1:0.0132, AUC:0.5028
# ###########################################################################
# 임곗값: 0.8905474796734585
# 오차 행렬
# [[899   1]
#  [895   5]]
# 정확도: 0.5022, 정밀도: 0.8333, 재현율: 0.0056, F1:0.0110, AUC:0.5022
# ###########################################################################
# 임곗값: 0.8923579652226428
# 오차 행렬
# [[899   1]
#  [896   4]]
# 정확도: 0.5017, 정밀도: 0.8000, 재현율: 0.0044, F1:0.0088, AUC:0.5017
# ###########################################################################
# 임곗값: 0.89332006647328
# 오차 행렬
# [[899   1]
#  [897   3]]
# 정확도: 0.5011, 정밀도: 0.7500, 재현율: 0.0033, F1:0.0066, AUC:0.5011
# ###########################################################################
# 임곗값: 0.8970142234695198
# 오차 행렬
# [[900   0]
#  [897   3]]
# 정확도: 0.5017, 정밀도: 1.0000, 재현율: 0.0033, F1:0.0066, AUC:0.5017
# ###########################################################################
# 임곗값: 0.8972555615744482
# 오차 행렬
# [[900   0]
#  [898   2]]
# 정확도: 0.5011, 정밀도: 1.0000, 재현율: 0.0022, F1:0.0044, AUC:0.5011
# ###########################################################################
# 임곗값: 0.9010564957474996
# 오차 행렬
# [[900   0]
#  [899   1]]
# 정확도: 0.5006, 정밀도: 1.0000, 재현율: 0.0011, F1:0.0022, AUC:0.5006
# ###########################################################################
# 임곗값: 0.9047665047379952
# 오차 행렬
# [[900   0]
#  [900   0]]
# 정확도: 0.5000, 정밀도: 0.0000, 재현율: 0.0000, F1:0.0000, AUC:0.5000
# ###########################################################################
# /Users/viceliln/Desktop/KDT_0900_Cho/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
prediction = Binarizer(threshold=0.49053045757631125).fit_transform(prediction_prob_class1)
get_evaluation(y_test, prediction, grid_random_forest, X_test)
# Out:
# 오차 행렬
# [[612 288]
#  [147 753]]
# 정확도: 0.7583, 정밀도: 0.7233, 재현율: 0.8367, F1:0.7759, AUC:0.7583
# ###########################################################################

# %%
import numpy as np
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

def precision_recall_curve_plot(y_test, prediction_proba_class1):
    precisions, recalls, thresholds = precision_recall_curve(y_test, prediction_proba_class1)
    
    # X축: threshold, Y축: 정밀도, 재현율 
    # 정밀도는 점선으로 표시
    plt.figure(figsize=(8,6))
    threshold_boundary = thresholds.shape[0]
    plt.plot(thresholds, precisions[0:threshold_boundary], linestyle='--', label='precision')
    plt.plot(thresholds, recalls[0:threshold_boundary], label='recall')
    
    # X축(threshold)의 Scale을 0 ~ 1 단위로 변경
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1),2))
    
    plt.xlabel('Threshold value'); plt.ylabel('Precision and Recall value')
    plt.legend()
    plt.grid()
    plt.show()

# Predict probabilities using the grid_random_forest
precision_recall_curve_plot(y_test, grid_random_forest.predict_proba(X_test)[:, 1])

# %%
from sklearn.metrics import roc_curve
def roc_curve_plot(y_test , prediction_proba_class1):
#     임계값에 따른 FPR, TPR 값
    fprs, tprs, thresholds = roc_curve(y_test ,prediction_proba_class1)

#     ROC Curve를 plot 곡선으로 그림. 
    plt.plot(fprs , tprs, label='ROC')
#     가운데 대각선 직선을 그림. 
#     TPR과 FPR이 동일한 비율로 떨어진다는 것은 모델이 양성과 음성을 구별하지 못한다는 것을 의미한다.
#     다른 분류기를 판단하기 위한 기준선으로 사용되며, 
#     대각선에 가까울 수록 예측에 사용하기 힘든 모델이라는 뜻이다.
    plt.plot([0, 1], [0, 1], 'k--', label='Standard')
    
    # X축(FPR)의 Scale을 0.1 단위로 변경
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1),2))
    plt.xlim(0,1); plt.ylim(0,1)
    plt.xlabel('FPR( 1 - Sensitivity )'); plt.ylabel('TPR( Recall )')
    plt.legend()
    plt.show()
    
roc_curve_plot(y_test, grid_random_forest.predict_proba(X_test)[:, 1] )
